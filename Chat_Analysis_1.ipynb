# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install emoji
# !pip install seaborn
# Out:
# Collecting emoji
#   Downloading emoji-2.14.1-py3-none-any.whl.metadata (5.7 kB)
# Downloading emoji-2.14.1-py3-none-any.whl (590 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 590.6/590.6 kB 7.5 MB/s eta 0:00:00
# Installing collected packages: emoji
# Successfully installed emoji-2.14.1
# Requirement already satisfied: seaborn in /usr/local/lib/python3.11/dist-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in /usr/local/lib/python3.11/dist-packages (from seaborn) (2.0.2)
# Requirement already satisfied: pandas>=1.2 in /usr/local/lib/python3.11/dist-packages (from seaborn) (2.2.2)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in /usr/local/lib/python3.11/dist-packages (from seaborn) (3.10.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (24.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)

# %%
import regex
import pandas as pd
import numpy as np
import emoji
from collections import Counter
import matplotlib.pyplot as plt
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
from matplotlib.ticker import MaxNLocator
from plotly import express as px
import seaborn as sns
from datetime import *
import datetime as dt

# %%
def startsWithDate(s):
    pattern = '^([0-9]+)(\/)([0-9]+)(\/)([0-9]+), ([0-9]+):([0-9]+)[ ]?(AM|PM|am|pm)? -'
    result = regex.match(pattern, s)
    if result:
        return True
    return False

# %%
def startsWithAuthor(s):
    patterns = [
        '([\w]+):',                        # First Name
        '([\w]+[\s]+[\w]+):',              # First Name + Last Name
        '([\w]+[\s]+[\w]+[\s]+[\w]+):',    # First Name + Middle Name + Last Name
        '([+]\d{2} \d{5} \d{5}):',         # Mobile Number (India)
        '([+]\d{2} \d{3} \d{3} \d{4}):',   # Mobile Number (US)
        '([+]\d{2} \d{4} \d{7})'           # Mobile Number (Europe)
    ]
    pattern = '^' + '|'.join(patterns)
    result = regex.match(pattern, s)
    if result:
        return True
    return False

# %%
def getDatapoint(line):
    splitline = line.split(' - ')
    dateTime = splitline[0]
    date, time = dateTime.split(", ")
    message = " ".join(splitline[1:])
    if startsWithAuthor(message):
        splitmessage = message.split(": ")
        author = splitmessage[0]
        message = " ".join(splitmessage[1:])
    else:
        author= None
    return date, time, author, message

# %%
data = []
conversation = r'/content/drive/MyDrive/WHATSAPP_CHAT/DATASET/Updated_chat_data.txt'
with open(conversation, encoding="utf-8") as fp:
    fp.readline()
    messageBuffer = []
    date, time, author = None, None, None
    while True:
        line = fp.readline()
        if not line:
            break
        line = line.strip()
        if startsWithDate(line):
            if len(messageBuffer) > 0:
                data.append([date, time, author, ' '.join(messageBuffer)])
            messageBuffer.clear()
            date, time, author, message = getDatapoint(line)
            messageBuffer.append(message)
        else:
            messageBuffer.append(line)

# %%
data
# Out:
# [['05/02/2020', '10:00 am', 'Ed', 'We share our knowledge here and pass year'],
#  ['05/02/2020', '10:01 am', 'Ed', '<Media omitted>'],
#  ['05/02/2020', '10:01 am', 'Ed', 'Easy to communicate 🤣🤣🤣'],
#  ['05/02/2020', '10:01 am', 'Rohit', '💪🏾'],
#  ['05/02/2020', '10:01 am', 'Rohit', 'yeah'],
#  ['05/02/2020', '12:22 pm', 'Ed', '<Media omitted>'],
#  ['05/02/2020', '12:22 pm', 'Ed', 'Guys? Haha'],
#  ['05/02/2020', '12:38 pm', 'Ed', 'You deleted this message'],
#  ['05/02/2020', '12:38 pm', 'Ed', 'One of the answer'],
#  ['05/02/2020', '12:39 pm', 'Rohit', '<Media omitted>'],
#  ['05/02/2020', '12:39 pm', 'Rohit', '<Media omitted>'],
#  ['05/02/2020', '12:39 pm', 'Rohit', '<Media omitted>'],
#  ['05/02/2020',
#   '12:39 pm',
#   'Rohit',
#   'My recursive, I studying sorting now and i will do all sorting question'],
#  ['05/02/2020', '12:39 pm', 'Rohit', 'And send here also'],
#  ['05/02/2020', '12:39 pm', 'Rohit', "Y'all check if tally"],
#  ['05/02/2020', '12:40 pm', 'Rohit', "Haven't start on tree and hash yet"],
#  ['05/02/2020', '12:40 pm', 'Ed', 'I doing hashing I send to u all also'],
#  ['05/02/2020', '12:40 pm', 'Rohit', '<Media omitted>'],
#  ['05/02/2020', '12:40 pm', 'Ed', 'Same with u'],
#  ['05/02/2020', '12:40 pm', 'Ed', 'I doing all the hashing'],
#  ['05/02/2020', '12:41 pm', 'Ed', '@60197773622 cab teach me recursive...'],
#  ['05/02/2020',
#   '12:41 pm',
#   'Rohit',
#   'i follow text book je duh, i need to study sorting lu'],
#  ['05/02/2020', '12:41 pm', 'Rohit', 'gimme time to coiver all 1 round lu'],
#  ['05/02/2020', '12:42 pm', 'Ed', 'Haha'],
#  ['05/02/2020', '12:42 pm', 'Ed', 'Hashing is easy'],
#  ['05/02/2020', '12:42 pm', 'Ed', 'Sorting take time'],
#  ['05/02/2020', '12:42 pm', 'Ed', 'I not yet read theory gg'],
#  ['05/02/2020', '12:52 pm', 'Rohit', 'slide 39 chapter 8'],
#  ['05/02/2020', '12:56 pm', 'Rohit', '<Media omitted>'],
#  ['05/02/2020', '12:56 pm', 'Rohit', 'i see many times dy on previous paret'],
#  ['05/02/2020',
#   '12:56 pm',
#   'Rohit',
#   'they call u to do recursive search code'],
#  ['05/02/2020', '12:57 pm', 'Rohit', 'or recursice sequnetial search code'],
#  ['05/02/2020', '12:57 pm', 'Rohit', 'big marks'],
#  ['05/02/2020', '12:57 pm', 'Rohit', 'algorith is in pseudocode'],
#  ['05/02/2020', '12:58 pm', 'Ed', 'Nono'],
#  ['05/02/2020', '12:58 pm', 'Rohit', 'b i'],
#  ['05/02/2020', '12:58 pm', 'Rohit', 'in 2017 and 2016 also alot'],
#  ['05/02/2020', '12:59 pm', 'Rohit', 'the pic is 287 jan 2018'],
#  ['05/02/2020', '12:59 pm', 'Ed', 'Hashing also have'],
#  ['05/02/2020', '12:59 pm', 'Ed', 'The code pary'],
#  ['05/02/2020', '12:59 pm', 'Ed', 'From 21 sep 2018'],
#  ['05/02/2020', '12:59 pm', 'Ed', '<Media omitted>'],
#  ['05/02/2020',
#   '12:59 pm',
#   'Ed',
#   'If you write in algorithm if you write in code.. I dunno'],
#  ['05/02/2020', '1:00 pm', 'Ed', 'Cos only algorithms can use english word'],
#  ['05/02/2020', '1:00 pm', 'Rohit', 'ur ans is in pseidocode'],
#  ['05/02/2020', '1:00 pm', 'Ed', '<Media omitted>'],
#  ['05/02/2020',
#   '1:00 pm',
#   'Rohit',
#   'both yeare 2019/2918 january come out algo/code of the search'],
#  ['05/02/2020', '1:01 pm', 'Ed', 'Ya'],
#  ['05/02/2020', '1:01 pm', 'Ed', 'But I will choose to write in algo'],
#  ['05/02/2020', '1:01 pm', 'Ed', 'Cos Ms teach already'],
#  ['05/02/2020', '1:01 pm', 'Rohit', 'pseudocde is how algo is written lol'],
#  ['05/02/2020', '1:01 pm', 'Rohit', 'u google that boss'],
#  ['05/02/2020', '1:01 pm', 'Rohit', 'the term LOL'],
#  ['05/02/2020', '1:01 pm', 'Ed', 'Actually got format'],
#  ['05/02/2020', '1:02 pm', 'Ed', '<Media omitted>'],
#  ['05/02/2020', '1:02 pm', 'Rohit', '<Media omitted>'],
#  ['05/02/2020', '1:02 pm', 'Ed', 'Yaya'],
#  ['05/02/2020', '1:02 pm', 'Ed', 'I not yet read gg..'],
#  ['05/02/2020', '1:02 pm', 'Rohit', 'kk ignore proceed with rest'],
#  ['05/02/2020', '1:02 pm', 'Ed', 'Kk bro'],
#  ['05/02/2020', '1:09 pm', 'Rohit', 'whatever yall done send here pls'],
#  ['05/02/2020', '1:09 pm', 'Rohit', 'bcuz easier to direct mark'],
#  ['05/02/2020', '1:09 pm', 'Rohit', 'keep asking very pening'],
#  ['05/02/2020',
#   '1:09 pm',
#   'Rohit',
#   'do dy direct send, im not talking about the whole set'],
#  ['05/02/2020', '1:09 pm', 'Rohit', 'im talking about each question'],
#  ['05/02/2020', '1:09 pm', 'Rohit', 'send je'],
#  ['05/02/2020',
#   '1:10 pm',
#   'Rohit',
#   'bcuz if i dont do also i will do by draft and check back'],
#  ['05/02/2020', '1:10 pm', 'Rohit', 'send quesdtion also thx'],
#  ['05/02/2020', '1:14 pm', 'Rohit', 'This message was deleted'],
#  ['05/02/2020', '1:14 pm', 'Rohit', 'This message was deleted'],
#  ['05/02/2020', '1:15 pm', 'Rohit', 'This message was deleted'],
#  ['05/02/2020', '1:15 pm', 'Rohit', 'This message was deleted'],
#  ['05/02/2020', '1:21 pm', 'Ed', '<Media omitted>'],
#  ['05/02/2020', '1:21 pm', 'Ed', '<Media omitted>'],
#  ['05/02/2020', '1:21 pm', 'Ed', '<Media omitted>'],
#  ['05/02/2020', '1:21 pm', 'Ed', '<Media omitted>'],
#  ['05/02/2020', '1:21 pm', 'Ed', '<Media omitted>'],
#  ['05/02/2020', '1:21 pm', 'Ed', '<Media omitted>'],
#  ['05/02/2020', '2:10 pm', 'Rohit', '<Media omitted>'],
#  ['05/02/2020', '2:10 pm', 'Rohit', 'even if no swap'],
#  ['05/02/2020', '2:10 pm', 'Rohit', 'is considered a pass'],
#  ['05/02/2020', '2:11 pm', 'Rohit', 'wait ah i double check'],
#  ['05/02/2020', '2:14 pm', 'Rohit', '<Media omitted>'],
#  ['05/02/2020',
#   '2:14 pm',
#   'Rohit',
#   'teacher got say about algo being able to track'],
#  ['05/02/2020', '2:14 pm', 'Rohit', 'see the note'],
#  ['05/02/2020',
#   '2:14 pm',
#   'Rohit',
#   'that why the highlight is the pass counter'],
#  ['05/02/2020', '2:15 pm', 'Rohit', 'see pass 3 and 4'],
#  ['05/02/2020', '2:15 pm', 'Rohit', 'already sorted'],
#  ['05/02/2020', '2:15 pm', 'Rohit', 'but is still considered as a pass'],
#  ['05/02/2020',
#   '2:15 pm',
#   'Ed',
#   'Why this buddle sort so different from Ms teach one..'],
#  ['05/02/2020', '2:16 pm', 'Ed', 'Bubble*'],
#  ['05/02/2020', '2:16 pm', 'Rohit', 'pass 6,7 insertion'],
#  ['05/02/2020', '2:16 pm', 'Rohit', 'yes'],
#  ['05/02/2020', '2:16 pm', 'Rohit', 'yes'],
#  ['05/02/2020', '2:17 pm', 'Rohit', 'yes u should'],
#  ['05/02/2020', '2:17 pm', 'Rohit', 'its proven'],
#  ['05/02/2020', '2:17 pm', 'Rohit', 'pivot quite gay'],
#  ['05/02/2020', '2:17 pm', 'Rohit', '...'],
#  ['05/02/2020', '2:58 pm', 'Rohit', 'yo in exam ah'],
#  ['05/02/2020', '2:58 pm', 'Rohit', 'need rto show ifl ifr all ah'],
#  ['05/02/2020', '2:58 pm', 'Rohit', 'for pivot'],
#  ['05/02/2020', '2:58 pm', 'Ed', 'Yes bri'],
#  ['05/02/2020', '2:59 pm', 'Ed', 'Must shoe'],
#  ['05/02/2020', '3:01 pm', 'Rohit', 'how much time wasted'],
#  ['05/02/2020', '3:02 pm', 'Rohit', 'drawing boxews'],
#  ['05/02/2020', '3:07 pm', 'Ed', 'I send the answer already'],
#  ['05/02/2020', '3:07 pm', 'Ed', 'Oh wait'],
#  ['05/02/2020', '3:07 pm', 'Ed', 'I send the other one'],
#  ['05/02/2020', '3:08 pm', 'Ed', 'The answer is from Yik han'],
#  ['05/02/2020', '3:09 pm', 'Ed', 'Wait ah'],
#  ['05/02/2020', '3:19 pm', 'Ed', '<Media omitted>'],
#  ['05/02/2020', '3:20 pm', 'Ed', 'Something like this'],
#  ['05/02/2020', '3:21 pm', 'Ed', 'Ya can cos is algo'],
#  ['05/02/2020', '3:21 pm', 'Ed', 'But if write code cannot'],
#  ['05/02/2020', '3:21 pm', 'Ed', 'Must follow liek yours'],
#  ['05/02/2020',
#   '3:21 pm',
#   'Rohit',
#   'Coding or algo, yes can the question say dy'],
#  ['05/02/2020',
#   '3:23 pm',
#   'Ed',
#   'In qick sort do we need to show the number of pass?'],
#  ['05/02/2020',
#   '3:24 pm',
#   'Rohit',
#   'X sure, maybe just simple numbering will do at the side, I research on9 on quick sort now some questions I stuck'],
#  ['05/02/2020',
#   '3:25 pm',
#   'Rohit',
#   'The method not adapting to the question, especially 2019 Jan'],
#  ['05/02/2020', '3:25 pm', 'Ed', 'i have the answer'],
#  ['05/02/2020', '3:25 pm', 'Ed', 'i think'],
#  ['05/02/2020', '3:25 pm', 'Ed', 'you mean the 2019 first question'],
#  ['05/02/2020', '3:25 pm', 'Rohit', 'Yeav'],
#  ['05/02/2020', '3:25 pm', 'Ed', 'wait sending now'],
#  ['05/02/2020',
#   '3:25 pm',
#   'Rohit',
#   'I seeing the context not the final answer'],
#  ['05/02/2020', '3:25 pm', 'Rohit', 'Marks there'],
#  ['05/02/2020', '3:26 pm', 'Ed', '<Media omitted>'],
#  ['05/02/2020', '3:26 pm', 'Ed', 'Wait I send images file better'],
#  ['05/02/2020', '3:26 pm', 'Rohit', 'Not this'],
#  ['05/02/2020', '3:26 pm', 'Rohit', '2019'],
#  ['05/02/2020',
#   '3:27 pm',
#   'Rohit',
#   'Still just send tho and what year this ah'],
#  ['05/02/2020', '3:27 pm', 'Ed', 'Cos very messy 🤣🤣 I do at part by part..'],
#  ['05/02/2020', '3:27 pm', 'Ed', '<Media omitted>'],
#  ['05/02/2020', '3:27 pm', 'Ed', '?'],
#  ['05/02/2020', '3:28 pm', 'Rohit', '<Media omitted>'],
#  ['05/02/2020', '3:28 pm', 'Rohit', 'Pei Ing answer'],
#  ['05/02/2020', '3:28 pm', 'Rohit', 'Jam 2019n'],
#  ['05/02/2020',
#   '3:28 pm',
#   'Rohit',
#   'I still doing my version, something confirm not right'],
#  ['05/02/2020',
#   '3:29 pm',
#   'Rohit',
#   "Will update here when I'm done with all sort and search questions for the pyq I cover"],
#  ['05/02/2020', '3:31 pm', 'Ed', '<Media omitted>'],
#  ['05/02/2020', '3:31 pm', 'Ed', 'This one'],
#  ['05/02/2020', '3:31 pm', 'Ed', '@60197773622'],
#  ['05/02/2020',
#   '3:32 pm',
#   'Ed',
#   'I did step by step I dunno exam give or not'],
#  ['05/02/2020', '3:52 pm', 'Ed', '<Media omitted>'],
#  ['05/02/2020', '3:52 pm', 'Ed', '<Media omitted>'],
#  ['05/02/2020', '3:52 pm', 'Ed', 'Sorry the writing'],
#  ['05/02/2020', '3:52 pm', 'Ed', 'Your is correct check already'],
#  ['05/02/2020', '5:08 pm', 'Ed', 'Write GB'],
#  ['05/02/2020', '5:09 pm', 'Ed', '<Media omitted>'],
#  ['05/02/2020', '5:09 pm', 'Ed', 'I GB cannot be hash'],
#  ['05/02/2020',
#   '5:09 pm',
#   'Ed',
#   'And in algorithm we say we hash four number behide'],
#  ['05/02/2020', '5:10 pm', 'Ed', 'The GB remains unmove'],
#  ['05/02/2020', '5:10 pm', 'Ed', 'That what I understand'],
#  ['05/02/2020', '5:11 pm', 'Ed', '@60197773622'],
#  ['05/02/2020', '5:12 pm', 'Ed', 'Ya'],
#  ['05/02/2020', '5:12 pm', 'Ed', 'Ada'],
#  ['05/02/2020', '5:15 pm', 'Ed', 'Anyone did 2 Feb 2017'],
#  ['05/02/2020',
#   '5:16 pm',
#   'Rohit',
#   'almost done all search and sort pyq, trying to send here by 6. Then i will proceed to hashing and later that tree'],
#  ['05/02/2020', '5:16 pm', 'Rohit', 'i do later let u know GB or nmot hahaha'],
#  ['05/02/2020', '5:16 pm', 'Ed', 'Kk Bro'],
#  ['05/02/2020', '5:17 pm', 'Rohit', 'gb at wher eha?'],
#  ['05/02/2020',
#   '5:18 pm',
#   'Rohit',
#   'what year ah, u can resend this page in full again thx'],
#  ['05/02/2020', '5:18 pm', 'Ed', 'I send the question wait a'],
#  ['05/02/2020', '5:19 pm', 'Ed', '<Media omitted>'],
#  ['05/02/2020', '5:19 pm', 'Ed', 'Here here here'],
#  ['05/02/2020', '5:38 pm', 'Rohit', 'if u see lecture slide ah'],
#  ['05/02/2020', '5:38 pm', 'Rohit', 'there have 1 example'],
#  ['05/02/2020', '5:39 pm', 'Rohit', '<Media omitted>'],
#  ['05/02/2020', '5:39 pm', 'Rohit', 'she did the val >'],
#  ['05/02/2020', '5:39 pm', 'Rohit', 'the condition of the if else'],
#  ['05/02/2020',
#   '5:40 pm',
#   'Rohit',
#   'so if i access any if check at any if else b4 i found the right one, i wrotee'],
#  ['05/02/2020', '5:40 pm', 'Rohit', 'this has pYQ on it'],
#  ['05/02/2020', '5:40 pm', 'Rohit', 'so i took this lo'],
#  ['05/02/2020', '5:40 pm', 'Rohit', 'even in ur pic'],
#  ['05/02/2020', '5:41 pm', 'Rohit', '<Media omitted>'],
#  ['05/02/2020', '5:41 pm', 'Rohit', 'x sure la'],
#  ['05/02/2020', '5:41 pm', 'Rohit', 'but i just do oh'],
#  ['05/02/2020', '5:41 pm', 'Rohit', 'dun have much examples'],
#  ['05/02/2020', '5:41 pm', 'Rohit', 'i just refer the lecture slide pyq one'],
#  ['05/02/2020', '5:44 pm', 'Rohit', 'i did not write that'],
#  ['05/02/2020', '5:45 pm', 'Rohit', 'yea'],
#  ['05/02/2020', '5:45 pm', 'Rohit', 'i wrote node.data'],
#  ['05/02/2020', '5:47 pm', 'Rohit', '<Media omitted>'],
#  ['05/02/2020', '5:47 pm', 'Rohit', '<Media omitted>'],
#  ['05/02/2020', '5:47 pm', 'Rohit', '<Media omitted>'],
#  ['05/02/2020', '5:47 pm', 'Rohit', '<Media omitted>'],
#  ['05/02/2020',
#   '5:47 pm',
#   'Rohit',
#   'Quick sort I x sure la, I just follow teacher method and always obey the conditions at every pass. Also I not very sure like teacher do only have 1 time pass the pivot directly to the middle'],
#  ['05/02/2020',
#   '5:48 pm',
#   'Rohit',
#   'Our question pass the pivot at the end so I just adapted the same formula and it works'],
#  ['05/02/2020',
#   '5:48 pm',
#   'Rohit',
#   "I Google online have other ways, but scare not applicable Bec the rubrics don't have that method"],
#  ['05/02/2020', '5:48 pm', 'Rohit', 'So I stick to her method'],
#  ['05/02/2020', '5:49 pm', 'Rohit', 'umm is binary tree chapter alot?'],
#  ['05/02/2020', '5:49 pm', 'Rohit', 'bcuz i dik to start hash or tree lu?'],
#  ['05/02/2020', '5:49 pm', 'Ed', 'Not much'],
#  ['05/02/2020', '5:49 pm', 'Rohit', 'ok i go with hash then'],
#  ['05/02/2020', '5:50 pm', 'Ed', 'I stack at chapter 6'],
#  ['05/02/2020', '5:50 pm', 'Ed', 'I dunno how to trace damn'],
#  ['05/02/2020',
#   '5:50 pm',
#   'Rohit',
#   'oh bruh u see the lecture lside i snap above'],
#  ['05/02/2020', '5:50 pm', 'Rohit', 'i see that only'],
#  ['05/02/2020', '5:50 pm', 'Rohit', 'on9 also same but abit diff also'],
#  ['05/02/2020', '5:51 pm', 'Ed', 'Wait'],
#  ['05/02/2020', '5:51 pm', 'Ed', 'I doing the hashing'],
#  ['05/02/2020', '5:51 pm', 'Ed', '2 may'],
#  ['05/02/2020', '5:51 pm', 'Ed', 'Wait ah'],
#  ['05/02/2020',
#   '5:54 pm',
#   'Rohit',
#   'Open addressing Linear probing Quadratic  probing Double hashing Separate Chaining'],
#  ['05/02/2020',
#   '5:54 pm',
#   'Rohit',
#   'all of these yall drill down studied is it?'],
#  ['05/02/2020', '5:56 pm', 'Rohit', 'pyq cover which one'],
#  ['05/02/2020',
#   '5:57 pm',
#   'Rohit',
#   'is tree chapter massive, mich say not so'],
#  ['05/02/2020', '5:59 pm', 'Ed', 'No need lot'],
#  ['05/02/2020', '5:59 pm', 'Ed', 'So far only tgree'],
#  ['05/02/2020', '5:59 pm', 'Ed', 'Liner, quadratic, separate'],
#  ['05/02/2020', '5:59 pm', 'Rohit', 'pls check @60183560200 @60163021381'],
#  ['05/02/2020', '5:59 pm', 'Rohit', 'these is importqant?'],
#  ['05/02/2020', '6:00 pm', 'Ed', 'May'],
#  ['05/02/2020', '6:00 pm', 'Ed', 'I not yet do..'],
#  ['05/02/2020', '6:00 pm', 'Ed', 'Wait I check back'],
#  ['05/02/2020', '6:00 pm', 'Ed', 'Cos alot of paper'],
#  ['05/02/2020', '6:00 pm', 'Ed', 'This not hush meh'],
#  ['05/02/2020', '6:00 pm', 'Rohit', 'yea, bcuz even if i stuidy deep these'],
#  ['05/02/2020', '6:00 pm', 'Rohit', 'no pyq'],
#  ['05/02/2020', '6:00 pm', 'Rohit', 'no way test the skill'],
#  ['05/02/2020',
#   '6:01 pm',
#   'Ed',
#   'Ermm you must know how to bulid a tree preorder, Inorder , post order'],
#  ['05/02/2020', '6:01 pm', 'Ed', 'And delete'],
#  ['05/02/2020',
#   '6:01 pm',
#   'Rohit',
#   'ok that noted, now i asking hash yall say majortiy is probe'],
#  ['05/02/2020',
#   '6:02 pm',
#   'Rohit',
#   'any othe pyq covering the other typoes of hash'],
#  ['05/02/2020', '6:03 pm', 'Ed', 'Got alot'],
#  ['05/02/2020', '6:03 pm', 'Ed', 'Ermm 2018 till 2019'],
#  ['05/02/2020', '6:03 pm', 'Ed', 'Have py'],
#  ['05/02/2020',
#   '6:04 pm',
#   'Rohit',
#   'okok so yall soi far postred here how many hash questions'],
#  ['05/02/2020', '6:05 pm', 'Rohit', 'm,ay 2018'],
#  ['05/02/2020', '6:06 pm', 'Rohit', 'oh damn la, u can repost them sorry wei'],
#  ['05/02/2020', '6:06 pm', 'Rohit', 'i scroll  die la'],
#  ['05/02/2020', '6:06 pm', 'Rohit', 'u got do ah'],
#  ['05/02/2020', '6:06 pm', 'Rohit', 'this'],
#  ['05/02/2020', '6:07 pm', 'Rohit', 'okok if posted here ill go hunting la'],
#  ['05/02/2020', '6:07 pm', 'Rohit', 'thx'],
#  ['05/02/2020', '6:07 pm', 'Rohit', '💪🏾💪🏾'],
#  ['05/02/2020', '6:07 pm', 'Ed', 'Wait'],
#  ['05/02/2020', '6:07 pm', 'Ed', 'Wiat ah'],
#  ['05/02/2020', '6:07 pm', 'Ed', 'Very easy no need to worry'],
#  ['05/02/2020', '6:08 pm', 'Ed', '<Media omitted>'],
#  ['05/02/2020', '6:08 pm', 'Ed', '<Media omitted>'],
#  ['05/02/2020', '6:08 pm', 'Ed', 'I sending the last quadratic prod'],
#  ['05/02/2020', '6:08 pm', 'Ed', '@60183560200 wait'],
#  ['05/02/2020', '6:08 pm', 'Ed', 'I doing your question'],
#  ['05/02/2020',
#   '6:10 pm',
#   'Rohit',
#   'yea this is mic one, yours i x cari lagi'],
#  ['05/02/2020',
#   '6:10 pm',
#   'Rohit',
#   'i tengah cover lecture briefly this chapter b4 i do myslef and check with his'],
#  ['05/02/2020', '6:11 pm', 'Rohit', 'there is sept 2019?'],
#  ['05/02/2020', '6:11 pm', 'Rohit', 'yo mic'],
#  ['05/02/2020', '6:11 pm', 'Rohit', 'wherer u get la'],
#  ['05/02/2020', '6:11 pm', 'Rohit', 'drive x de'],
#  ['05/02/2020', '6:11 pm', 'Rohit', 'sept 2018 have'],
#  ['05/02/2020', '6:11 pm', 'Ed', '<Media omitted>'],
#  ['05/02/2020',
#   '6:11 pm',
#   'Ed',
#   'http://eprints.tarc.edu.my/cgi/search/simple?q=+BACS2063&_action_search=Search&_action_search=Search&_order=bytitle&basic_srchtype=ALL&_satisfyall=ALL'],
#  ['05/02/2020', '6:11 pm', 'Ed', 'use this already'],
#  ['05/02/2020', '6:11 pm', 'Ed', 'google drive no longer have'],
#  ['05/02/2020', '6:12 pm', 'Rohit', 'campbell'],
#  ['05/02/2020', '6:12 pm', 'Ed', '😄'],
#  ['05/02/2020', '6:12 pm', 'Ed', 'better than be safe than sorry bro'],
#  ['05/02/2020', '6:12 pm', 'Rohit', 'yea haha'],
#  ['05/02/2020', '6:12 pm', 'Ed', 'Okkk'],
#  ['05/02/2020', '6:13 pm', 'Ed', 'I must focus on my work jor'],
#  ['05/02/2020',
#   '6:13 pm',
#   'Rohit',
#   'ok damn la i just need all hash papers answer, later i go hunt 1 by 1 here again'],
#  ['05/02/2020', '6:13 pm', 'Ed', '.... Just finish reading all..'],
#  ['05/02/2020', '6:13 pm', 'Ed', 'Got'],
#  ['05/02/2020', '6:13 pm', 'Ed', 'Three only'],
#  ['05/02/2020', '6:14 pm', 'Rohit', 'this and'],
#  ['05/02/2020', '6:14 pm', 'Rohit', 'this'],
#  ['05/02/2020',
#   '6:15 pm',
#   'Rohit',
#   'pei ing if u can repost means dope la, just the hashing ones'],
#  ['05/02/2020', '6:15 pm', 'Rohit', 'unles u say u same la with him'],
#  ['05/02/2020', '6:15 pm', 'Rohit', 'then no need'],
#  ['05/02/2020', '6:17 pm', 'Rohit', 'anyone got do 28 jan 2019 hashing'],
#  ['05/02/2020', '6:17 pm', 'Rohit', '@60163021381 i dont see u posted'],
#  ['05/02/2020', '6:17 pm', 'Ed', 'The hashing ah'],
#  ['05/02/2020', '6:17 pm', 'Ed', 'I trying to rewrite everything'],
#  ['05/02/2020', '6:17 pm', 'Rohit', 'yea'],
#  ['05/02/2020', '6:17 pm', 'Ed', 'Cos too messy'],
#  ['05/02/2020', '6:18 pm', 'Rohit', '🙏🙆\u200d♂'],
#  ['05/02/2020', '6:18 pm', 'Ed', '<Media omitted>'],
#  ['05/02/2020', '6:19 pm', 'Ed', '<Media omitted>'],
#  ['05/02/2020', '6:19 pm', 'Ed', 'Rem3 the k+n^2 damn important'],
#  ['05/02/2020', '6:19 pm', 'Rohit', 'woah this which year'],
#  ['05/02/2020', '6:19 pm', 'Rohit', '2feb what year'],
#  ['05/02/2020', '6:19 pm', 'Ed', '2017'],
#  ['05/02/2020',
#   '6:20 pm',
#   'Rohit',
#   'Rem3 the k+n^2 damn important under quadratic ah'],
#  ['05/02/2020', '6:21 pm', 'Ed', 'Remember *'],
#  ['05/02/2020', '6:21 pm', 'Ed', 'Yup'],
#  ['05/02/2020', '6:22 pm', 'Ed', 'Remember once have collision then 1^2'],
#  ['05/02/2020', '6:22 pm', 'Ed', 'The second time is 2^2'],
#  ['05/02/2020', '6:22 pm', 'Ed', 'K is the number'],
#  ['05/02/2020',
#   '6:23 pm',
#   'Ed',
#   'http://eprints.tarc.edu.my/12619/1/BACS2063.pdf'],
#  ['05/02/2020', '6:23 pm', 'Ed', '@60183560200 this have the chain also'],
#  ['05/02/2020', '6:24 pm', 'Ed', 'I doing 2 may'],
#  ['05/02/2020',
#   '6:25 pm',
#   'Rohit',
#   'bruh include year also haha i legit lost which year if u dun say'],
#  ['05/02/2020', '6:25 pm', 'Ed', 'Kk sorry'],
#  ['05/02/2020',
#   '6:27 pm',
#   'Ed',
#   '7 may 2019 chain hashing 21 September 2018 - liner prod 2 Feb 2017 - quadratic'],
#  ['05/02/2020', '6:27 pm', 'Ed', '<Media omitted>'],
#  ['05/02/2020', '6:28 pm', 'Ed', '<Media omitted>'],
#  ['05/02/2020', '6:29 pm', 'Ed', 'You deleted this message'],
#  ['05/02/2020', '6:53 pm', 'Ed', '<Media omitted>'],
#  ['05/02/2020', '6:53 pm', 'Rohit', 'key % number'],
#  ['05/02/2020', '6:53 pm', 'Rohit', 'hw u do that in  claculatoer'],
#  ['05/02/2020', '6:59 pm', 'Rohit', '🙆\u200d♂🙏'],
#  ['05/02/2020', '7:00 pm', 'Ed', '@60183560200'],
#  ['05/02/2020', '7:02 pm', 'Ed', '@60183560200'],
#  ['05/02/2020', '7:02 pm', 'Ed', '<Media omitted>'],
#  ['05/02/2020', '7:03 pm', 'Ed', 'ohh..'],
#  ['05/02/2020', '7:03 pm', 'Rohit', 'eh my bubble'],
#  ['05/02/2020', '7:03 pm', 'Rohit', 'and inmsertion'],
#  ['05/02/2020', '7:03 pm', 'Rohit', 'follow lecture note 100% oh'],
#  ['05/02/2020', '7:05 pm', 'Ed', 'i want to makan also ahha'],
#  ['05/02/2020', '7:06 pm', 'Ed', 'later close alredy haha'],
#  ['05/02/2020', '7:08 pm', 'Rohit', 'woah'],
#  ['05/02/2020', '7:08 pm', 'Rohit', 'lecture lain'],
#  ['05/02/2020', '7:08 pm', 'Rohit', 'notes lain'],
#  ['05/02/2020', '7:11 pm', 'Rohit', 'u see additional notes tuesday'],
#  ['05/02/2020', '7:11 pm', 'Rohit', 'sudden;y same as me and lecture notes'],
#  ['05/02/2020', '7:11 pm', 'Rohit', 'additional notes thursday lain pulak'],
#  ['05/02/2020', '7:13 pm', 'Rohit', 'tuesday and lecture slide did'],
#  ['05/02/2020', '7:13 pm', 'Rohit', 'single digit mulyiple swqap'],
#  ['05/02/2020',
#   '7:13 pm',
#   'Rohit',
#   'then some place do multiple digit multiple/single swaps'],
#  ['05/02/2020', '7:14 pm', 'Rohit', 'both also get 6 pass'],
#  ['05/02/2020', '7:14 pm', 'Rohit', 'lert it go lol'],
#  ['05/02/2020', '7:14 pm', 'Rohit', 'diff methods i presume'],
#  ['05/02/2020', '7:17 pm', 'Rohit', 'any of ur pyq'],
#  ['05/02/2020', '7:17 pm', 'Rohit', 'have collision?'],
#  ['05/02/2020', '7:17 pm', 'Rohit', '<Media omitted>'],
#  ['05/02/2020', '7:17 pm', 'Rohit', 'linear probing collision'],
#  ['05/02/2020', '7:47 pm', 'Rohit', 'ignore this'],
#  ['05/02/2020', '7:47 pm', 'Rohit', 'wrongly asked'],
#  ['05/02/2020', '7:47 pm', 'Rohit', 'having issue here'],
#  ['05/02/2020',
#   '7:51 pm',
#   'Rohit',
#   'i meant like 2 may 2018 all key x clash, they all individual'],
#  ['05/02/2020',
#   '7:51 pm',
#   'Rohit',
#   'didint had to i+1 until find vacant spot'],
#  ['05/02/2020', '7:51 pm', 'Rohit', 'what is key ah'],
#  ['05/02/2020', '7:51 pm', 'Rohit', 'is it the key or index'],
#  ['05/02/2020', '7:52 pm', 'Rohit', 'ok nmoted'],
#  ['05/02/2020', '7:53 pm', 'Ed', 'Ya'],
#  ['05/02/2020', '7:53 pm', 'Rohit', 'my bad wrongly see'],
#  ['05/02/2020',
#   '7:54 pm',
#   'Ed',
#   'So is like first collision you can use k+1^2 Then after the second one is k+2^2 After that is k+3^2 the third collision'],
#  ['05/02/2020', '7:54 pm', 'Ed', 'Remember'],
#  ['05/02/2020', '7:54 pm', 'Ed', 'The remainder is the index number'],
#  ['05/02/2020', '7:54 pm', 'Rohit', 'k is what'],
#  ['05/02/2020', '7:54 pm', 'Rohit', 'the index number?'],
#  ['05/02/2020', '7:54 pm', 'Rohit', 'or key boss'],
#  ['05/02/2020', '7:55 pm', 'Rohit', 'lets say k is 5'],
#  ['05/02/2020', '7:55 pm', 'Rohit', 'this is 3rd colision'],
#  ['05/02/2020', '7:55 pm', 'Rohit', 'sk 5 + 3^2'],
#  ['05/02/2020',
#   '7:56 pm',
#   'Rohit',
#   'k 5 + 3^2 = the new index to put the value'],
#  ['05/02/2020', '7:56 pm', 'Ed', 'Key Bro'],
#  ['05/02/2020', '7:56 pm', 'Rohit', 'oh lol okok noted'],
#  ['05/02/2020', '7:56 pm', 'Ed', 'Yup and divide on the size'],
#  ['05/02/2020',
#   '7:56 pm',
#   'Ed',
#   'Get the reminder you will have the index number'],
#  ['05/02/2020', '7:56 pm', 'Rohit', 'ah thats where i went wrong'],
#  ['05/02/2020', '7:56 pm', 'Rohit', 'to do the modulus again'],
#  ['05/02/2020', '7:56 pm', 'Ed', 'Yup'],
#  ['05/02/2020', '7:56 pm', 'Ed', 'That easy Bro'],
#  ['05/02/2020', '7:57 pm', 'Ed', 'I still trying on chpater 6 damn'],
#  ['05/02/2020',
#   '7:57 pm',
#   'Rohit',
#   'cry la, hmm need fast do tree also if i have time still i call u latenight if u havent sleep'],
#  ['05/02/2020', '7:57 pm', 'Rohit', 'if u still cant la'],
#  ['05/02/2020', '7:57 pm', 'Rohit', 'i try settle until tree lu'],
#  ['05/02/2020', '7:59 pm', 'Rohit', '<Media omitted>'],
#  ['05/02/2020', '7:59 pm', 'Rohit', 'lets say'],
#  ['05/02/2020', '7:59 pm', 'Rohit', 'the 10'],
#  ['05/02/2020', '7:59 pm', 'Rohit', 'it want to enter at 3'],
#  ['05/02/2020', '7:59 pm', 'Rohit', 'but 3 is filled after k+1'],
#  ['05/02/2020', '7:59 pm', 'Rohit', 'does the same formula pply to key 10'],
#  ['05/02/2020',
#   '8:01 pm',
#   'Rohit',
#   'so basically the formula is saved separately for each unqiue index'],
#  ['05/02/2020', '8:01 pm', 'Rohit', 'like if we begin collison at index 2'],
#  ['05/02/2020', '8:01 pm', 'Ed', 'Yup'],
#  ['05/02/2020', '8:01 pm', 'Ed', 'All will start again'],
#  ['05/02/2020',
#   '8:01 pm',
#   'Rohit',
#   'so all index 2 colisions will carry on with the k+n^2'],
#  ['05/02/2020',
#   '8:01 pm',
#   'Rohit',
#   'so all index 3 colisions will carry on with the k+n^2'],
#  ['05/02/2020', '8:01 pm', 'Rohit', 'etc'],
#  ['05/02/2020',
#   '8:01 pm',
#   'Ed',
#   'As long the collision is in different key value will restore'],
#  ['05/02/2020', '8:02 pm', 'Ed', 'Correct'],
#  ['05/02/2020', '8:02 pm', 'Rohit', 'ok got it'],
#  ['05/02/2020', '8:02 pm', 'Ed', '@60197773622'],
#  ['05/02/2020', '8:02 pm', 'Ed', 'You see 16'],
#  ['05/02/2020', '8:02 pm', 'Ed', 'Put in two ma'],
#  ['05/02/2020', '8:03 pm', 'Ed', 'That mean 16 +9 /7'],
#  ['05/02/2020', '8:03 pm', 'Ed', 'Get the reminder'],
#  ['05/02/2020', '8:03 pm', 'Rohit', 'woah what'],
#  ['05/02/2020', '8:04 pm', 'Ed', 'Sorry'],
#  ['05/02/2020', '8:04 pm', 'Ed', 'Is 16+2/7'],
#  ['05/02/2020',
#   '8:04 pm',
#   'Ed',
#   'And get the reminder that mean 16 will be in index 6'],
#  ['05/02/2020', '8:04 pm', 'Rohit', 'what about 39'],
#  ['05/02/2020', '8:05 pm', 'Rohit', '6+2^2/7?'],
#  ['05/02/2020', '8:05 pm', 'Rohit', '1sr collision is k+1'],
#  ['05/02/2020', '8:05 pm', 'Rohit', '2nd is K+2^2'],
#  ['05/02/2020', '8:06 pm', 'Rohit', '6+2^2/7?'],
#  ['05/02/2020', '8:06 pm', 'Ed', 'Bro'],
#  ['05/02/2020', '8:06 pm', 'Ed', 'Why take 6'],
#  ['05/02/2020', '8:06 pm', 'Rohit', '16*'],
#  ['05/02/2020', '8:06 pm', 'Rohit', 'soryy'],
#  ['05/02/2020', '8:07 pm', 'Ed', 'Yes'],
#  ['05/02/2020', '8:07 pm', 'Rohit', 'what about the 39'],
#  ['05/02/2020',
#   '8:07 pm',
#   'Rohit',
#   'what formula u use i testing my underastanidn based on ur answer'],
#  ['05/02/2020', '8:09 pm', 'Ed', 'Do this'],
#  ['05/02/2020', '8:09 pm', 'Ed', 'See your understanding'],
#  ['05/02/2020', '8:09 pm', 'Ed', 'If u can do np'],
#  ['05/02/2020', '8:09 pm', 'Ed', 'And this'],
#  ['05/02/2020', '8:09 pm', 'Rohit', 'u see ah 39 cannot put on 5'],
#  ['05/02/2020', '8:09 pm', 'Rohit', 'bcuz 5 has 26'],
#  ['05/02/2020', '8:10 pm', 'Ed', '<Media omitted>'],
#  ['05/02/2020', '8:10 pm', 'Rohit', 'this is damn good question u know'],
#  ['05/02/2020', '8:10 pm', 'Rohit', 'yea gonna do awhile more'],
#  ['05/02/2020', '8:10 pm', 'Rohit', '39 lompat 2 kali'],
#  ['05/02/2020', '8:10 pm', 'Ed', 'Ya so you jump for space'],
#  ['05/02/2020', '8:10 pm', 'Ed', 'Cos is 2^2'],
#  ['05/02/2020', '8:10 pm', 'Rohit', 'i seeing the formula'],
#  ['05/02/2020', '8:11 pm', 'Rohit', 'now i see thru'],
#  ['05/02/2020', '8:11 pm', 'Rohit', 'the collions probe'],
#  ['05/02/2020', '8:11 pm', 'Rohit', 'is bnasded on the key'],
#  ['05/02/2020', '8:11 pm', 'Rohit', 'not index'],
#  ['05/02/2020',
#   '8:12 pm',
#   'Rohit',
#   'number of times the key clash will decide the n'],
#  ['05/02/2020', '8:12 pm', 'Rohit', 'i trying to drill down the formula'],
#  ['05/02/2020', '8:12 pm', 'Rohit', 'i did it dy'],
#  ['05/02/2020', '8:12 pm', 'Rohit', 'thx'],
#  ['05/02/2020', '8:12 pm', 'Rohit', '❤'],
#  ['05/02/2020', '8:14 pm', 'Ed', 'Yup yip'],
#  ['05/02/2020', '8:15 pm', 'Rohit', 'the cmapbell got do ah'],
#  ['05/02/2020', '8:17 pm', 'Ed', '<Media omitted>'],
#  ['05/02/2020',
#   '8:24 pm',
#   'Rohit',
#   'can u send me this question @60163021381'],
#  ['05/02/2020', '8:24 pm', 'Rohit', 'for cm,apbell'],
#  ['05/02/2020', '8:24 pm', 'Rohit', 'u have the answer posted here'],
#  ['05/02/2020', '8:24 pm', 'Rohit', 'but i dun see the question'],
#  ['05/02/2020', '8:26 pm', 'Rohit', 'also no dfouble hashing question'],
#  ['05/02/2020', '8:26 pm', 'Rohit', 'should i skip?'],
#  ['05/02/2020', '8:26 pm', 'Rohit', 'ok noted'],
#  ['05/02/2020', '8:45 pm', 'Ed', 'Hushing'],
#  ['05/02/2020', '8:46 pm', 'Ed', 'Yaya'],
#  ['05/02/2020', '9:04 pm', 'Ed', '<Media omitted>'],
#  ['05/02/2020', '9:04 pm', 'Rohit', 'i dun see anyone popsted'],
#  ['05/02/2020', '9:04 pm', 'Rohit', 'hashing for january 2018'],
#  ['05/02/2020', '9:04 pm', 'Ed', 'Guys'],
#  ['05/02/2020', '9:04 pm', 'Ed', 'Shit'],
#  ['05/02/2020', '9:04 pm', 'Ed', '<Media omitted>'],
#  ['05/02/2020', '9:05 pm', 'Ed', 'Double hashing'],
#  ['05/02/2020', '9:05 pm', 'Ed', '28?'],
#  ['05/02/2020', '9:05 pm', 'Rohit', 'yea'],
#  ['05/02/2020',
#   '9:05 pm',
#   'Ed',
#   'I not going to do.. Cos wnat to read through the theory and do the chapter 6'],
#  ['05/02/2020', '9:06 pm', 'Rohit', 'foudn it'],
#  ['05/02/2020',
#   '9:29 pm',
#   'Ed',
#   '@60183560200  can give me you april 7 questio on recursive'],
#  ['05/02/2020', '9:30 pm', 'Ed', '2017'],
#  ['05/02/2020', '9:30 pm', 'Ed', '<Media omitted>'],
#  ['05/02/2020',
#   '9:34 pm',
#   'Rohit',
#   'campbell 2019 jan pei ing u have the question'],
#  ['05/02/2020', '9:35 pm', 'Rohit', 'this septtember'],
#  ['05/02/2020', '9:35 pm', 'Rohit', '<Media omitted>'],
#  ['05/02/2020', '9:35 pm', 'Rohit', 'ur answer stated jan oh'],
#  ['05/02/2020',
#   '9:36 pm',
#   'Rohit',
#   'if u completed more from that set dont midn send here arigato'],
#  ['05/02/2020', '9:36 pm', 'Rohit', 'okok np gl tmrw'],
#  ['05/02/2020', '9:57 pm', 'Ed', 'Ya I dun understand'],
#  ['05/02/2020', '9:57 pm', 'Ed', 'Why twach me...'],
#  ['05/02/2020', '9:58 pm', 'Ed', 'Tmr really'],
#  ['05/02/2020', '9:58 pm', 'Rohit', 'canteen red bricks i 7 am there'],
#  ['05/02/2020', '9:59 pm', 'Rohit', 'now at tree'],
#  ['05/02/2020', '9:59 pm', 'Rohit', 'if i end early'],
#  ['05/02/2020', '9:59 pm', 'Rohit', 'i try pm u'],
#  ['05/02/2020', '9:59 pm', 'Rohit', 'see u wawake'],
#  ['05/02/2020', '9:59 pm', 'Rohit', 'any shortcut on tree?'],
#  ['05/02/2020', '9:59 pm', 'Ed', 'Teach me @60183560200'],
#  ['05/02/2020', '10:01 pm', 'Rohit', 'pre post and inverse'],
#  ['05/02/2020', '10:01 pm', 'Rohit', 'all share the same tree correct?'],
#  ['05/02/2020', '10:10 pm', 'Rohit', 'tunngu mich bro'],
#  ['05/02/2020',
#   '10:10 pm',
#   'Rohit',
#   'i will call u at 11.30 like that if can make it'],
#  ['05/02/2020', '10:11 pm', 'Rohit', 'aisde from draiwing trace box'],
#  ['05/02/2020', '10:11 pm', 'Rohit', 'see i got do 1 question'],
#  ['05/02/2020', '10:11 pm', 'Rohit', 'to write code also'],
#  ['05/02/2020', '10:11 pm', 'Rohit', 'the data come from the tabel'],
#  ['05/02/2020', '10:16 pm', 'Rohit', 'This message was deleted'],
#  ['05/02/2020', '10:32 pm', 'Rohit', '@60163021381 u there'],
#  ['05/02/2020',
#   '10:33 pm',
#   'Rohit',
#   'i can make a quick 15 mins call explain in depth la but it gotta be now'],
#  ['05/02/2020',
#   '10:33 pm',
#   'Rohit',
#   'bcuz i wanna do the tree pyq and revise all theory balik'],
#  ['05/02/2020', '10:33 pm', 'Rohit', '@60163021381 ?'],
#  ['05/02/2020', '10:43 pm', 'Ed', 'Bro wait ah'],
#  ['05/02/2020', '10:43 pm', 'Rohit', '<Media omitted>'],
#  ['05/02/2020', '10:43 pm', 'Rohit', "Check y'all"],
#  ['05/02/2020', '10:44 pm', 'Rohit', 'I accidentally wrote terbalik'],
#  ['05/02/2020',
#   '10:44 pm',
#   'Rohit',
#   "Don't forget ah the method x end tau, and another method call dy"],
#  ['05/02/2020', '10:44 pm', 'Rohit', 'So u plus the return from bottom to up'],
#  ['05/02/2020', '10:44 pm', 'Rohit', "Don't hafak.this"],
#  ['05/02/2020', '10:45 pm', 'Ed', '...'],
#  ['05/02/2020',
#   '10:45 pm',
#   'Rohit',
#   'U need to understand or else quite gg if the question pusing'],
#  ['05/02/2020', '10:45 pm', 'Rohit', 'U free anot'],
#  ['05/02/2020', '10:45 pm', 'Rohit', 'I can call now'],
#  ['05/02/2020', '10:45 pm', 'Ed', 'Ya can'],
#  ['05/02/2020',
#   '11:21 pm',
#   'Rohit',
#   'gl all tmrw, it was great effort here today'],
#  ['05/02/2020', '11:21 pm', 'Rohit', 'looking forward for future collab haha'],
#  ['05/02/2020', '11:21 pm', 'Rohit', '💪🏾💪🏾💪🏾😘'],
#  ['05/02/2020', '11:21 pm', 'Ed', 'Ya bro!'],
#  ['05/02/2020', '11:21 pm', 'Ed', 'Hope all the best guys..'],
#  ['05/02/2020', '11:21 pm', 'Ed', 'Really stress out haha'],
#  ['05/02/2020', '11:29 pm', 'Ed', '! Let do it'],
#  ['06/02/2020',
#   '6:14 pm',
#   'Rohit',
#   "Lecture 13 he did simple discussion sadly he used a application online couldn't take the answer, the answer above is part of it"],
#  ['06/02/2020',
#   '6:15 pm',
#   'Rohit',
#   'There was more complex questions with good answer but before I snapped he padam'],
#  ['06/02/2020', '6:15 pm', 'Rohit', 'I ask Kampar dy they also dont have'],
#  ['06/02/2020',
#   '6:16 pm',
#   'Rohit',
#   "I remembered who went that day it was the voting day also, was some fella at the front row but not our degree didn't got a chance to ask them"],
#  ['06/02/2020', '6:16 pm', 'Rohit', 'So I guess study all 1-10'],
#  ['06/02/2020', '6:21 pm', 'Ed', 'You all start already?'],
#  ['06/02/2020', '6:21 pm', 'Ed', 'Wow...'],
#  ['06/02/2020', '6:21 pm', 'Ed', 'Chapter 10 no come out'],
#  ['06/02/2020', '6:21 pm', 'Ed', 'I want to his class on last week of 14'],
#  ['06/02/2020', '6:21 pm', 'Ed', 'Went*'],
#  ['06/02/2020',
#   '6:23 pm',
#   'Rohit',
#   'Going batu caves later sembang, tomorrow start lo but I doubt can last minute la alot to understand, hafal quite gg'],
#  ['06/02/2020', '6:23 pm', 'Rohit', 'My mid term ah I call him double check'],
#  ['06/02/2020', '6:23 pm', 'Rohit', 'From 71 to 79 I think'],
#  ['06/02/2020', '6:23 pm', 'Rohit', 'Open textbook infront him'],
#  ['06/02/2020',
#   '6:24 pm',
#   'Rohit',
#   "He ah don't understand passive English take note"],
#  ['06/02/2020', '6:24 pm', 'Ed', 'Gg'],
#  ['06/02/2020',
#   '6:24 pm',
#   'Rohit',
#   "Also don't use sophisticated English terms to combine multiple words into 1"],
#  ['06/02/2020', '6:24 pm', 'Ed', 'Walao..'],
#  ['06/02/2020', '6:24 pm', 'Ed', 'Mean we must same same'],
#  ['06/02/2020', '6:24 pm', 'Ed', 'Like note..'],
#  ['06/02/2020',
#   '6:24 pm',
#   'Rohit',
#   'Legit side by side him until he mark me right haha yeah'],
#  ['06/02/2020', '6:24 pm', 'Rohit', 'Need use full terms basically'],
#  ['06/02/2020', '6:24 pm', 'Rohit', 'Haish sad'],
#  ['06/02/2020', '6:24 pm', 'Ed', '...'],
#  ['06/02/2020', '6:25 pm', 'Ed', 'Crazy'],
#  ['06/02/2020', '6:34 pm', 'Ed', '🤣🤣🤣'],
#  ['06/02/2020', '6:36 pm', 'Ed', 'I dunno le haha'],
#  ['07/02/2020', '12:48 pm', 'Ed', 'what to study ah'],
#  ['07/02/2020', '12:48 pm', 'Rohit', '1-10'],
#  ['07/02/2020', '12:49 pm', 'Ed', '10 he say no come out'],
#  ['07/02/2020', '12:49 pm', 'Rohit', '11 no out'],
#  ['07/02/2020', '12:49 pm', 'Rohit', '10 bila he said'],
#  ['07/02/2020', '12:49 pm', 'Ed', 'oh'],
#  ['07/02/2020', '12:49 pm', 'Ed', 'got 11'],
#  ['07/02/2020', '12:49 pm', 'Ed', 'kk xD'],
#  ['07/02/2020', '12:49 pm', 'Ed', 'need to study now'],
#  ['07/02/2020', '12:49 pm', 'Rohit', 'in lecrture he say ma'],
#  ['07/02/2020', '12:49 pm', 'Rohit', 'on week 13'],
#  ['07/02/2020', '12:49 pm', 'Ed', 'haizz'],
#  ['07/02/2020', '12:49 pm', 'Rohit', 'woah 11 x de oh'],
#  ['07/02/2020',
#   '12:50 pm',
#   'Rohit',
#   'no meh in lecture hje said last chapter wont out'],
#  ['07/02/2020', '12:50 pm', 'Ed', 'if i last day study you think i fail  ?'],
#  ['07/02/2020', '12:50 pm', 'Ed', 'xD'],
#  ['07/02/2020', '12:50 pm', 'Ed', 'just asking xD'],
#  ['07/02/2020',
#   '12:50 pm',
#   'Rohit',
#   'his paper need to grind theory with industrial example'],
#  ['07/02/2020', '12:50 pm', 'Rohit', 'if u waste time thinking theory'],
#  ['07/02/2020', '12:50 pm', 'Rohit', 'u wont give proper example'],
#  ['07/02/2020', '12:50 pm', 'Rohit', 'so might not gg la but maybe score low'],
#  ['07/02/2020', '12:51 pm', 'Ed', 'i see'],
#  ['07/02/2020', '12:51 pm', 'Ed', 'kk'],
#  ['07/02/2020', '12:51 pm', 'Ed', 'the harmon process need to draw out'],
#  ['07/02/2020', '12:52 pm', 'Ed', 'HOW AH ?'],
#  ['07/02/2020', '12:54 pm', 'Rohit', 'so betetr 2 day la bro'],
#  ['07/02/2020', '12:54 pm', 'Ed', 'Ya start now'],
#  ['07/02/2020', '12:54 pm', 'Ed', 'Anyone did note'],
#  ['07/02/2020', '12:54 pm', 'Ed', 'Wnat to share xD'],
#  ['07/02/2020', '12:54 pm', 'Ed', 'Haha'],
#  ['07/02/2020',
#   '12:55 pm',
#   'Rohit',
#   'i start tmrw, haha today many fella cuti go makan2 lu bro'],
#  ['07/02/2020', '12:55 pm', 'Rohit', 'esok mula'],
#  ['07/02/2020', '12:55 pm', 'Rohit', '😂'],
#  ['07/02/2020', '12:55 pm', 'Rohit', 'harmon process need hafal'],
#  ['07/02/2020', '12:55 pm', 'Rohit', 'bcuz if u dun hafal u cannot draw'],
#  ['07/02/2020',
#   '12:56 pm',
#   'Rohit',
#   'the drawing is based on what u hafal bcuz its like a graph'],
#  ['07/02/2020',
#   '12:58 pm',
#   'Rohit',
#   'oh 1 thing i want ask if yall have examples for supporting main points, in pyq pls do share'],
#  ['07/02/2020', '12:58 pm', 'Rohit', 'bcuz bpm need so many examples'],
#  ['07/02/2020', '2:32 pm', 'Ed', '<Media omitted>'],
#  ['07/02/2020', '2:32 pm', 'Ed', 'I think he going to come out the same same'],
#  ['07/02/2020', '2:32 pm', 'Ed', 'He have been the same question since 2017'],
#  ['07/02/2020', '2:32 pm', 'Ed', 'Lol'],
#  ['07/02/2020', '2:32 pm', 'Ed', '1) harom thing 2)draw'],
#  ['07/02/2020', '2:32 pm', 'Ed', '🤣'],
#  ['08/02/2020', '12:58 pm', 'Ed', 'anyone finish reading and did pass year'],
#  ['08/02/2020', '2:11 pm', 'Rohit', 'The theory alot ah?'],
#  ['08/02/2020', '2:11 pm', 'Rohit', 'In your POV'],
#  ['08/02/2020', '2:11 pm', 'Ed', 'Actually'],
#  ['08/02/2020', '2:12 pm', 'Ed', 'If understand nothing much to read'],
#  ['08/02/2020', '2:12 pm', 'Ed', 'But pass year'],
#  ['08/02/2020', '2:12 pm', 'Ed', 'Abit challenge'],
#  ['08/02/2020',
#   '2:20 pm',
#   'Rohit',
#   "The pyq I seeing the question also but I haven't tried, trying to digest all theory. Maybe I'll do a few questions tomorrow but not fully completed because I see the pyq dont have a definite answer la"],
#  ['08/02/2020',
#   '2:20 pm',
#   'Rohit',
#   'Macam open end answers or close to rubrics answer'],
#  ['08/02/2020', '2:20 pm', 'Rohit', 'Alot of drawings oh'],
#  ['08/02/2020', '2:30 pm', 'Ed', 'Yup'],
#  ['08/02/2020', '2:34 pm', 'Ed', '<Media omitted>'],
#  ['08/02/2020', '7:04 pm', 'Ed', '<Media omitted>'],
#  ['08/02/2020', '7:04 pm', 'Ed', '<Media omitted>'],
#  ['08/02/2020',
#   '7:04 pm',
#   'Ed',
#   '@60197773622  if you have all the answer for tutorial'],
#  ['08/02/2020', '7:04 pm', 'Ed', 'Can send all'],
#  ['08/02/2020', '7:04 pm', 'Ed', 'Wilsom'],
#  ['08/02/2020', '7:04 pm', 'Ed', 'I want to risk'],
#  ['08/02/2020', '7:04 pm', 'Ed', 'Just read all'],
#  ['08/02/2020', '7:04 pm', 'Ed', 'And pass year just do one ppaer 2019'],
#  ['08/02/2020', '7:15 pm', 'Rohit', '@60183560200 u still need mine ah?'],
#  ['08/02/2020', '7:16 pm', 'Ed', '@60197773622  I need 9,10'],
#  ['08/02/2020', '7:16 pm', 'Rohit', '<Media omitted>'],
#  ['08/02/2020', '7:16 pm', 'Rohit', '<Media omitted>'],
#  ['08/02/2020', '7:16 pm', 'Rohit', '<Media omitted>'],
#  ['08/02/2020', '7:16 pm', 'Rohit', '<Media omitted>'],
#  ['08/02/2020',
#   '7:16 pm',
#   'Rohit',
#   'This one I snap from chung Huei, she completed all properly.'],
#  ['08/02/2020', '7:16 pm', 'Rohit', '8 9 10'],
#  ['08/02/2020', '7:17 pm', 'Rohit', 'Her answer all ask sir wan'],
#  ['08/02/2020',
#   '7:19 pm',
#   'Rohit',
#   'Idk la doing the pyq is good la give u a broader understanding on how to answer, but I feel the theory need to secure hard'],
#  ['08/02/2020', '7:19 pm', 'Rohit', 'Because all pyq goreng'],
#  ['08/02/2020', '7:19 pm', 'Rohit', 'Looks same but if u actually read ah'],
#  ['08/02/2020', '7:19 pm', 'Rohit', 'The case study is sophisticated'],
#  ['08/02/2020', '7:20 pm', 'Ed', 'Ya agree'],
#  ['08/02/2020', '7:20 pm', 'Ed', 'Very open close question'],
#  ['08/02/2020',
#   '7:20 pm',
#   'Rohit',
#   "I doubt la y'all will risk at not doing pyq but as long u know fromat to write ok dy"],
#  ['08/02/2020', '7:20 pm', 'Rohit', 'At least 1 or 2 set do la'],
#  ['08/02/2020',
#   '7:20 pm',
#   'Rohit',
#   'The tutorial is different than pyq answering techniques'],
#  ['08/02/2020', '7:21 pm', 'Ed', 'i think i doing 2019 and 2018'],
#  ['08/02/2020', '7:21 pm', 'Ed', 'once donw i share ba'],
#  ['08/02/2020', '7:21 pm', 'Ed', 'cos i doing reading liao'],
#  ['08/02/2020',
#   '7:21 pm',
#   'Rohit',
#   "Okok dope I'll cover my theory all but I'll do tomorrow and share my version on the exact question you did"],
#  ['08/02/2020',
#   '7:21 pm',
#   'Rohit',
#   'Then u get to see 2 version of the answer'],
#  ['08/02/2020', '7:22 pm', 'Rohit', 'Say in specific what set u doing'],
#  ['08/02/2020', '7:22 pm', 'Rohit', '@60183560200 take note on the set'],
#  ['08/02/2020',
#   '7:22 pm',
#   'Rohit',
#   'Because if we do many set also, we got no any confirmation on what is right because open ended'],
#  ['08/02/2020', '7:22 pm', 'Rohit', 'So better to see variations on each set'],
#  ['08/02/2020', '7:23 pm', 'Ed', 'ya kk'],
#  ['08/02/2020', '7:23 pm', 'Ed', 'i do this two'],
#  ['08/02/2020', '7:23 pm', 'Ed', 'after dinner will be back around  9'],
#  ['08/02/2020', '9:15 pm', 'Ed', '<Media omitted>'],
#  ['08/02/2020', '9:15 pm', 'Ed', 'Is it the life cycle of BPM?'],
#  ['08/02/2020', '9:15 pm', 'Ed', 'Wow'],
#  ['08/02/2020', '9:15 pm', 'Ed', 'Ask like so different le'],
#  ['08/02/2020', '9:16 pm', 'Ed', '<Media omitted>'],
#  ['08/02/2020', '9:16 pm', 'Ed', 'Ya ya'],
#  ['08/02/2020', '9:16 pm', 'Ed', 'The way he ask so not straight forward'],
#  ['08/02/2020', '9:16 pm', 'Ed', 'No wonder I no see'],
#  ['08/02/2020', '9:16 pm', 'Ed', 'Cos I write my own note'],
#  ['08/02/2020', '9:17 pm', 'Ed', 'Forget the part'],
#  ['08/02/2020', '9:34 pm', 'Ed', 'i will do the py tmr morning'],
#  ['08/02/2020', '9:34 pm', 'Ed', 'i covering some chapter'],
#  ['08/02/2020', '9:34 pm', 'Ed', 'if you all donw just send here'],
#  ['08/02/2020', '9:34 pm', 'Ed', 'sorry cos i miss out a part'],
#  ['08/02/2020', '9:36 pm', 'Ed', 'wow'],
#  ['08/02/2020', '9:36 pm', 'Ed', 'xD'],
#  ['08/02/2020', '9:36 pm', 'Ed', '@60183560200  Xd'],
#  ['08/02/2020',
#   '9:36 pm',
#   'Rohit',
#   'hahha baru balik open house, wish me luck tmrw'],
#  ['08/02/2020', '9:36 pm', 'Rohit', 'rush kaw all'],
#  ['08/02/2020', '9:36 pm', 'Ed', 'LIKE YOU XD so chilling'],
#  ['08/02/2020', '9:36 pm', 'Ed', '@60197773622'],
#  ['08/02/2020', '9:36 pm', 'Rohit', '3 house wei'],
#  ['08/02/2020', '9:36 pm', 'Rohit', 'how to say noi'],
#  ['08/02/2020', '9:36 pm', 'Ed', 'if need note tell me'],
#  ['08/02/2020', '9:36 pm', 'Rohit', 'i cry la say no'],
#  ['08/02/2020', '9:36 pm', 'Ed', 'i done some already'],
#  ['08/02/2020', '9:36 pm', 'Rohit', 'i got la morning'],
#  ['08/02/2020', '9:36 pm', 'Rohit', 'sikit2'],
#  ['08/02/2020', '9:36 pm', 'Ed', 'really just understand the note'],
#  ['08/02/2020', '9:37 pm', 'Ed', 'cos no point remember liao not like ERP'],
#  ['08/02/2020', '9:37 pm', 'Ed', 'go enjoy'],
#  ['08/02/2020', '9:37 pm', 'Ed', 'like that i also go date liao'],
#  ['08/02/2020', '9:37 pm', 'Ed', 'xD'],
#  ['08/02/2020', '9:50 pm', 'Rohit', '😂😂😂👏🏽'],
#  ['08/02/2020', '11:29 pm', 'Ed', 'i tmr only do pass year xD'],
#  ['08/02/2020', '11:29 pm', 'Ed', 'LAZY'],
#  ['08/02/2020', '11:29 pm', 'Ed', 'just finish reading lol'],
#  ['08/02/2020', '11:29 pm', 'Rohit', 'hmm fighting hard ah'],
#  ['08/02/2020',
#   '11:29 pm',
#   'Rohit',
#   'i gonna knowck out tmrw starting early esok'],
#  ['08/02/2020', '11:30 pm', 'Ed', 'why'],
#  ['08/02/2020',
#   '11:30 pm',
#   'Ed',
#   'you said like xD something going to happened'],
#  ['08/02/2020', '11:30 pm', 'Ed', 'i with you bro'],
#  ['08/02/2020', '11:30 pm', 'Ed', '9:00am will start doing'],
#  ['08/02/2020',
#   '11:30 pm',
#   'Rohit',
#   'need to sober up la......if i dont means tmrw gg la'],
#  ['08/02/2020',
#   '11:30 pm',
#   'Rohit',
#   'kinda regret last minute but life eh 😂😂😂'],
#  ['08/02/2020',
#   '11:31 pm',
#   'Rohit',
#   'yea same will be here until malam lewat'],
#  ['08/02/2020',
#   '11:31 pm',
#   'Ed',
#   '🤣🤣🤣 Well guess last paper let finish in a high tune!'],
#  ['08/02/2020', '11:31 pm', 'Ed', '🎶🎶🎶🎶'],
#  ['08/02/2020', '11:31 pm', 'Rohit', '🌚💃'],
#  ['08/02/2020', '11:32 pm', 'Ed', 'keep this group next exam'],
#  ['08/02/2020', '11:32 pm', 'Ed', 'we can diucess more paper'],
#  ['08/02/2020', '11:32 pm', 'Ed', '!!!!'],
#  ['08/02/2020', '11:32 pm', 'Rohit', '👉🏿👍🏿'],
#  ['08/02/2020', '11:32 pm', 'Ed', 'ok la guess do our best ba'],
#  ['09/02/2020', '8:58 am', 'Rohit', 'what is the password?'],
#  ['09/02/2020',
#   '8:58 am',
#   'Rohit',
#   'i click ah he download then try to enter he ask password'],
#  ['09/02/2020', '8:58 am', 'Ed', 'Your student Id and your password'],
#  ['09/02/2020', '9:00 am', 'Rohit', 'lol gg  cant'],
#  ['09/02/2020', '9:00 am', 'Rohit', 'idk i use my pass and id'],
#  ['09/02/2020', '9:00 am', 'Rohit', 'what mopnth the paper'],
#  ['09/02/2020', '9:00 am', 'Rohit', 'i go duinf in drive'],
#  ['09/02/2020', '9:00 am', 'Ed', 'Ermm February'],
#  ['09/02/2020', '9:00 am', 'Rohit', '<2'],
#  ['09/02/2020', '9:00 am', 'Rohit', '<#'],
#  ['09/02/2020', '9:00 am', 'Rohit', '❤'],
#  ['09/02/2020', '9:01 am', 'Ed', 'Wow you all start already'],
#  ['09/02/2020', '9:01 am', 'Rohit', 'oh how u open wei'],
#  ['09/02/2020', '9:01 am', 'Ed', 'Ya le'],
#  ['09/02/2020', '9:02 am', 'Ed', 'I cannot open le'],
#  ['09/02/2020', '9:02 am', 'Rohit', 'walao my id 1900189 and pass .....'],
#  ['09/02/2020', '9:02 am', 'Ed', 'In phone'],
#  ['09/02/2020', '9:02 am', 'Rohit', 'MY GOD'],
#  ['09/02/2020', '9:02 am', 'Rohit', 'gg wei pei ing low key examiner'],
#  ['09/02/2020', '9:02 am', 'Rohit', 'this also @60183560200 boss'],
#  ['09/02/2020', '9:02 am', 'Rohit', 'send the doc also here'],
#  ['09/02/2020', '11:02 am', 'Ed', 'well'],
#  ['09/02/2020', '11:02 am', 'Ed', 'still lazying xxD'],
#  ['09/02/2020', '11:02 am', 'Ed', 'HAHA'],
#  ['09/02/2020', '11:03 am', 'Ed', 'Ya'],
#  ['09/02/2020', '11:03 am', 'Ed', 'Shit'],
#  ['09/02/2020', '11:03 am', 'Ed', '🤣🤣🤣🤣'],
#  ['09/02/2020', '11:25 am', 'Ed', '@60197773622'],
#  ['09/02/2020', '11:25 am', 'Ed', 'we waiting your answer xD'],
#  ['09/02/2020', '11:25 am', 'Ed', 'GOGOG'],
#  ['09/02/2020', '12:05 pm', 'Ed', '<Media omitted>'],
#  ['09/02/2020', '12:05 pm', 'Ed', 'You guys have any ideas?'],
#  ['09/02/2020', '12:08 pm', 'Ed', 'Ya same'],
#  ['09/02/2020', '12:08 pm', 'Ed', 'But wnat actor say la actor'],
#  ['09/02/2020', '12:08 pm', 'Ed', 'Walao'],
#  ['09/02/2020', '12:08 pm', 'Ed', 'The question really tricky le'],
#  ['09/02/2020', '12:09 pm', 'Ed', '😂😂😂'],
#  ['09/02/2020', '12:09 pm', 'Ed', 'I go through already'],
#  ['09/02/2020', '12:09 pm', 'Ed', 'But just based on my understanding haha'],
#  ['09/02/2020', '5:35 pm', 'Ed', 'how guys ?'],
#  ['09/02/2020',
#   '5:37 pm',
#   'Rohit',
#   'Still in theory, I trying to hafal la not browse through. Now at 7'],
#  ['09/02/2020', '5:38 pm', 'Rohit', 'After 10 I do the pyq send here'],
#  ['09/02/2020',
#   '5:38 pm',
#   'Rohit',
#   'I intend to do pyq without seeing the bookn'],
#  ['09/02/2020', '5:38 pm', 'Ed', 'I see kk'],
#  ['09/02/2020', '6:34 pm', 'Rohit', 'is WFMS'],
#  ['09/02/2020', '6:34 pm', 'Rohit', 'reslly that crucial'],
#  ['09/02/2020', '6:53 pm', 'Rohit', 'also the archetecture of WFMS and BPMS'],
#  ['09/02/2020', '6:53 pm', 'Rohit', 'that one srsly have to know ah'],
#  ['09/02/2020',
#   '6:54 pm',
#   'Rohit',
#   'anyone did analysis on multiple sets of pyq'],
#  ['09/02/2020',
#   '6:54 pm',
#   'Rohit',
#   '@60183560200 what ur six sense sensing 😂'],
#  ['09/02/2020', '6:58 pm', 'Rohit', 'notes like hafal the entire achitecture'],
#  ['09/02/2020', '6:58 pm', 'Rohit', 'and know each part does what'],
#  ['09/02/2020', '6:59 pm', 'Rohit', 'is this what u did?'],
#  ['09/02/2020', '7:00 pm', 'Rohit', 'also where is the calculation chapter'],
#  ['09/02/2020', '7:00 pm', 'Rohit', 'i cant find oh'],
#  ['09/02/2020', '7:00 pm', 'Ed', 'Just know the bpms'],
#  ['09/02/2020', '7:00 pm', 'Ed', 'Bpms is important'],
#  ['09/02/2020', '7:00 pm', 'Ed', 'Wfms just know what is it'],
#  ['09/02/2020', '7:01 pm', 'Ed', 'Based on the pass year'],
#  ['09/02/2020', '7:01 pm', 'Ed', 'Very rare come out'],
#  ['09/02/2020', '7:01 pm', 'Ed', 'But honestly... Chpater 9 very heavily'],
#  ['09/02/2020', '7:01 pm', 'Rohit', 'on both or just wfms'],
#  ['09/02/2020', '7:01 pm', 'Ed', 'Wfms'],
#  ['09/02/2020', '7:01 pm', 'Ed', 'Bpms is very common question'],
#  ['09/02/2020', '7:01 pm', 'Rohit', 'heavily out in pyq?'],
#  ['09/02/2020', '7:01 pm', 'Rohit', 'oh'],
#  ['09/02/2020', '7:01 pm', 'Rohit', 'damn wei'],
#  ['09/02/2020', '7:01 pm', 'Ed', 'I mema the topic itself'],
#  ['09/02/2020', '7:02 pm', 'Ed', 'The pass year wfsm very rare'],
#  ['09/02/2020', '7:02 pm', 'Ed', 'The pass few year never come out'],
#  ['09/02/2020', '7:02 pm', 'Ed', 'And the calculations very important'],
#  ['09/02/2020', '7:02 pm', 'Ed', 'Super siper'],
#  ['09/02/2020', '7:03 pm', 'Ed', '<Media omitted>'],
#  ['09/02/2020',
#   '7:03 pm',
#   'Ed',
#   "I guess won't come out ba... For this calculation"],
#  ['09/02/2020', '7:31 pm', 'Ed', 'Sorry guya'],
#  ['09/02/2020', '7:32 pm', 'Ed', '<Media omitted>'],
#  ['09/02/2020', '7:32 pm', 'Ed', '<Media omitted>'],
#  ['09/02/2020', '7:32 pm', 'Ed', '<Media omitted>'],
#  ['09/02/2020', '7:32 pm', 'Ed', 'I did not finish'],
#  ['09/02/2020', '7:32 pm', 'Ed', 'I dun have mood to do'],
#  ['09/02/2020', '7:32 pm', 'Ed', 'So I decided to go Yolo tmr 😂😂😂😂'],
#  ['09/02/2020', '7:32 pm', 'Ed', '@60197773622  xD'],
#  ['09/02/2020',
#   '7:33 pm',
#   'Rohit',
#   'haha i understand bro i also ah seeing all my tutorials now, if i cant answer a question in draft points looking at the pyuq'],
#  ['09/02/2020', '7:33 pm', 'Rohit', 'means im n ot ready lo'],
#  ['09/02/2020', '7:33 pm', 'Rohit', 'i not gonna write anything'],
#  ['09/02/2020', '7:34 pm', 'Rohit', 'lerceh'],
#  ['09/02/2020', '7:34 pm', 'Rohit', 'use mind write je haha'],
#  ['09/02/2020', '7:34 pm', 'Ed', 'Same'],
#  ['09/02/2020',
#   '7:34 pm',
#   'Rohit',
#   'haha after grad open workshop how to goreng and pass'],
#  ['09/02/2020', '7:35 pm', 'Rohit', 'part time cadh'],
#  ['09/02/2020',
#   '7:35 pm',
#   'Ed',
#   'Not need lar look what tutorial bring there open book lar'],
#  ['09/02/2020',
#   '7:35 pm',
#   'Rohit',
#   'some tutorial quest. have sir pov answer mayybe worth a look'],
#  ['09/02/2020', '7:36 pm', 'Ed', 'Ya'],
#  ['09/02/2020', '7:36 pm', 'Ed', 'He say will come out'],
#  ['09/02/2020', '8:31 pm', 'Rohit', '<Media omitted>'],
#  ['09/02/2020', '8:31 pm', 'Rohit', 'what is the last one'],
#  ['09/02/2020', '8:31 pm', 'Rohit', 'BPNM model'],
#  ['09/02/2020', '8:32 pm', 'Rohit', 'is it teh same as above'],
#  ['09/02/2020', '8:32 pm', 'Rohit', 'oh so they test x and + also la'],
#  ['09/02/2020', '8:34 pm', 'Rohit', 'textbook got examples on + ah'],
#  ['09/02/2020', '8:34 pm', 'Rohit', 'u have seen any'],
#  ['09/02/2020', '8:34 pm', 'Rohit', 'chapter 6 dun have'],
#  ['09/02/2020', '8:35 pm', 'Ed', 'Draw only'],
#  ['09/02/2020', '8:35 pm', 'Rohit', 'the question said simultanously'],
#  ['09/02/2020', '8:35 pm', 'Ed', '<Media omitted>'],
#  ['09/02/2020', '8:35 pm', 'Rohit', 'meanng +'],
#  ['09/02/2020', '8:35 pm', 'Rohit', 'parallel'],
#  ['09/02/2020', '8:35 pm', 'Ed', 'Like that'],
#  ['09/02/2020', '8:35 pm', 'Ed', 'Example'],
#  ['09/02/2020', '8:35 pm', 'Ed', 'Done xD'],
#  ['09/02/2020', '8:36 pm', 'Rohit', 'ok dope thx'],
#  ['09/02/2020', '8:37 pm', 'Rohit', 'eh yall did ah'],
#  ['09/02/2020', '8:37 pm', 'Rohit', 'the calculations'],
#  ['09/02/2020', '8:38 pm', 'Rohit', 'for question 3'],
#  ['09/02/2020', '8:38 pm', 'Rohit', 'of 6 febuary 2018'],
#  ['09/02/2020', '8:38 pm', 'Ed', '<Media omitted>'],
#  ['09/02/2020', '8:38 pm', 'Ed', 'I think like that'],
#  ['09/02/2020', '8:38 pm', 'Ed', '0.6 and 0.4 need to calculate'],
#  ['09/02/2020', '8:42 pm', 'Rohit', 'why iu have'],
#  ['09/02/2020', '8:42 pm', 'Rohit', 'extra 5 at the back'],
#  ['09/02/2020', '8:50 pm', 'Ed', 'Oh shit'],
#  ['09/02/2020', '8:50 pm', 'Ed', 'I write wrong'],
#  ['09/02/2020', '8:50 pm', 'Ed', 'Cos I did this paper in 25 min 😂😂😂'],
#  ['09/02/2020', '8:51 pm', 'Ed', 'Taht why my writing sorry haha haha'],
#  ['09/02/2020', '8:51 pm', 'Ed', '<Media omitted>'],
#  ['09/02/2020',
#   '8:51 pm',
#   'Rohit',
#   'Haha NVM i just referring doing in draft je, i see that question how bpms helps bpmn lifecyvleb'],
#  ['09/02/2020', '8:51 pm', 'Rohit', 'Mad la'],
#  ['09/02/2020', '8:52 pm', 'Rohit', 'Wait I think I got see it b4'],
#  ['09/02/2020', '8:52 pm', 'Ed', 'I see'],
#  ['09/02/2020', '8:53 pm', 'Ed', 'Wow'],
#  ['09/02/2020', '8:53 pm', 'Rohit', 'Haish sticky note all'],
#  ['09/02/2020', '8:53 pm', 'Rohit', 'Me empty as I received'],
#  ['09/02/2020', '8:53 pm', 'Rohit', 'Using online slides je'],
#  ['09/02/2020', '8:53 pm', 'Ed', 'Ya..'],
#  ['09/02/2020', '8:53 pm', 'Rohit', '<Media omitted>'],
#  ['09/02/2020', '8:53 pm', 'Rohit', '<Media omitted>'],
#  ['09/02/2020', '8:54 pm', 'Rohit', '<Media omitted>'],
#  ['09/02/2020', '8:54 pm', 'Rohit', '<Media omitted>'],
#  ['09/02/2020', '8:54 pm', 'Ed', '<Media omitted>'],
#  ['09/02/2020', '8:54 pm', 'Ed', 'Haizz'],
#  ['09/02/2020', '8:54 pm', 'Ed', 'Guys tmr....'],
#  ['09/02/2020', '8:54 pm', 'Ed', 'Hope easy question'],
#  ['09/02/2020', '8:54 pm', 'Rohit', 'He updated chpster 7 slide'],
#  ['09/02/2020', '8:55 pm', 'Rohit', 'Idk la that waste analysis one'],
#  ['09/02/2020', '8:55 pm', 'Rohit', '3 versions that chpster'],
#  ['09/02/2020', '8:55 pm', 'Rohit', 'Maybe I say maybe he take note'],
#  ['09/02/2020', '8:55 pm', 'Ed', '<Media omitted>'],
#  ['09/02/2020', '8:55 pm', 'Rohit', '<Media omitted>'],
#  ['09/02/2020', '8:56 pm', 'Ed', 'Ya ya'],
#  ['09/02/2020', '8:56 pm', 'Ed', 'That one must read'],
#  ['09/02/2020', '8:56 pm', 'Ed', 'He mentioned alot in tutorial'],
#  ['09/02/2020', '8:56 pm', 'Rohit', 'He summarize dy in lecture slide'],
#  ['09/02/2020', '8:56 pm', 'Rohit', 'Easier to read'],
#  ['09/02/2020', '9:38 pm', 'Ed', 'cos you all have tutorial 6'],
#  ['09/02/2020', '9:39 pm', 'Rohit', '<Media omitted>'],
#  ['09/02/2020', '9:39 pm', 'Rohit', '<Media omitted>'],
#  ['09/02/2020', '9:39 pm', 'Rohit', '<Media omitted>'],
#  ['09/02/2020', '9:40 pm', 'Rohit', 'My version'],
#  ['09/02/2020', '9:47 pm', 'Rohit', '@60183560200 send T6 ur diagram'],
#  ['09/02/2020', '9:47 pm', 'Rohit', 'can?'],
#  ['09/02/2020', '9:47 pm', 'Rohit', 'my diagram quite whack'],
#  ['09/02/2020', '9:54 pm', 'Ed', 'Guys'],
#  ['09/02/2020', '9:54 pm', 'Ed', 'Nite'],
#  ['09/02/2020', '9:54 pm', 'Ed', '🤣🤣🤣'],
#  ['09/02/2020', '9:55 pm', 'Rohit', 'gl tmrw, nite boss'],
#  ['09/02/2020', '9:55 pm', 'Ed', '🤣🤣'],
#  ['09/02/2020', '9:55 pm', 'Ed', 'You too bro'],
#  ['09/02/2020', '9:55 pm', 'Ed', '@60183560200 too xD'],
#  ['09/02/2020', '9:56 pm', 'Ed', 'End with high note tmr!'],
#  ['09/02/2020', '10:39 pm', 'Rohit', '<Media omitted>'],
#  ['09/02/2020', '10:39 pm', 'Rohit', '<Media omitted>'],
#  ['09/02/2020',
#   '10:39 pm',
#   'Rohit',
#   "Bpm t8 I sent didn't have proper explanation but the question damn important"],
#  ['09/02/2020',
#   '10:39 pm',
#   'Rohit',
#   'I realized I had my own version that I ask from sir'],
#  ['09/02/2020',
#   '10:40 pm',
#   'Rohit',
#   'This is sir answer as I recall when wrote'],
#  ['09/02/2020',
#   '10:40 pm',
#   'Rohit',
#   'The question came out in February 6 2018 alsob'],
#  ['09/02/2020', '10:40 pm', 'Rohit', 'And January 2017/18'],
#  ['09/02/2020', '10:40 pm', 'Rohit', 'Sorry bout'],
#  ['09/02/2020', '10:40 pm', 'Rohit', '<Media omitted>'],
#  ['09/02/2020', '10:40 pm', 'Rohit', 'Blur'],
#  ['09/02/2020', '10:48 pm', 'Rohit', '<Media omitted>'],
#  ['09/02/2020',
#   '10:49 pm',
#   'Rohit',
#   'This is my version, that i directly took from the huge ass textbook at page 300 something as the lecture said to'],
#  ['09/02/2020', '10:49 pm', 'Rohit', '<Media omitted>'],
#  ['09/02/2020', '10:49 pm', 'Ed', 'Guys'],
#  ['09/02/2020', '10:49 pm', 'Rohit', 'Fuxkimg whack Wei wahstapp camera'],
#  ['09/02/2020', '10:49 pm', 'Rohit', 'Default camera macam Nixon'],
#  ['09/02/2020', '10:50 pm', 'Ed', 'The how bpms support process redesign'],
#  ['09/02/2020', '10:50 pm', 'Ed', 'Is not chpater 8 ah'],
#  ['09/02/2020', '10:50 pm', 'Ed', '<Media omitted>'],
#  ['09/02/2020',
#   '10:51 pm',
#   'Rohit',
#   'Process redesign is broke down to 2 no meh'],
#  ['09/02/2020',
#   '10:51 pm',
#   'Rohit',
#   'High level redesign which like minor changes improvement and the detail process design'],
#  ['09/02/2020', '10:51 pm', 'Rohit', 'Which is complete new process'],
#  ['09/02/2020',
#   '10:51 pm',
#   'Rohit',
#   'So they say the bpms help what at that stage'],
#  ['09/02/2020',
#   '10:52 pm',
#   'Rohit',
#   'So basically sir explaination is that la durong my class'],
#  ['09/02/2020', '10:52 pm', 'Ed', 'Where?'],
#  ['09/02/2020', '10:52 pm', 'Rohit', 'yea but dk from where'],
#  ['09/02/2020', '10:54 pm', 'Ed', 'Sorry this I mean  this'],
#  ['09/02/2020', '10:54 pm', 'Ed', '<Media omitted>'],
#  ['09/02/2020', '10:55 pm', 'Ed', '<Media omitted>'],
#  ['09/02/2020', '10:55 pm', 'Ed', 'So is this one ah'],
#  ['09/02/2020', '10:55 pm', 'Rohit', 'u take bpms definition'],
#  ['09/02/2020',
#   '10:55 pm',
#   'Rohit',
#   'and adapt to task in process redesgn phase'],
#  ['09/02/2020', '10:55 pm', 'Rohit', 'which is to-be'],
#  ['09/02/2020', '10:56 pm', 'Ed', 'I remember is sir writ one'],
#  ['09/02/2020', '10:57 pm', 'Rohit', '<Media omitted>'],
#  ['09/02/2020', '10:57 pm', 'Rohit', 'see same quextion'],
#  ['09/02/2020', '10:57 pm', 'Rohit', 'discovery is as-is'],
#  ['09/02/2020', '10:57 pm', 'Rohit', 'use bpms modelling tool to do'],
#  ['09/02/2020', '10:57 pm', 'Ed', 'What is this answer'],
#  ['09/02/2020', '10:57 pm', 'Rohit', 'my tutorial lo'],
#  ['09/02/2020', '10:57 pm', 'Rohit', 'HAHHAHA'],
#  ['09/02/2020',
#   '10:57 pm',
#   'Ed',
#   'I say using bpms it will help to turn as-is to to-be'],
#  ['09/02/2020', '10:57 pm', 'Ed', '🤣🤣🤣🤣'],
#  ['09/02/2020', '10:57 pm', 'Rohit', 'u know right what all phase is about'],
#  ['09/02/2020', '10:57 pm', 'Rohit', 'bcuz if dk means gg'],
#  ['09/02/2020', '10:57 pm', 'Rohit', 'nono lol'],
#  ['09/02/2020', '10:58 pm', 'Ed', 'Ya Confim'],
#  ['09/02/2020', '10:58 pm', 'Rohit', 'bpms is a tool'],
#  ['09/02/2020', '10:58 pm', 'Rohit', 'baiscally yea'],
#  ['09/02/2020', '10:58 pm', 'Rohit', 'but cant say la make asis to to be'],
#  ['09/02/2020', '10:58 pm', 'Rohit', 'u need to to explain analysis stage'],
#  ['09/02/2020', '10:59 pm', 'Rohit', 'b4 u say make to be using bpms'],
#  ['09/02/2020', '10:59 pm', 'Rohit', 'u direct say asis to tobe'],
#  ['09/02/2020',
#   '10:59 pm',
#   'Ed',
#   'So basically is just explain the two of the phase right'],
#  ['09/02/2020', '10:59 pm', 'Rohit', 'means gg'],
#  ['09/02/2020', '10:59 pm', 'Rohit', 'no'],
#  ['09/02/2020', '10:59 pm', 'Rohit', 'explain what bpms involvemnt in here'],
#  ['09/02/2020', '10:59 pm', 'Rohit', '<Media omitted>'],
#  ['09/02/2020', '10:59 pm', 'Rohit', 'bpms archiotectyure'],
#  ['09/02/2020', '10:59 pm', 'Rohit', 'have modelling toold'],
#  ['09/02/2020', '11:00 pm', 'Rohit', 'and automation'],
#  ['09/02/2020',
#   '11:00 pm',
#   'Rohit',
#   'hence u need to say bpms can model the asis'],
#  ['09/02/2020', '11:00 pm', 'Rohit', 'and tobe'],
#  ['09/02/2020', '11:00 pm', 'Rohit', 'and automate the tobe after modelling'],
#  ['09/02/2020', '11:01 pm', 'Rohit', 'u see process datvbabasde\\'],
#  ['09/02/2020', '11:01 pm', 'Rohit', 'send the process to engine'],
#  ['09/02/2020',
#   '11:01 pm',
#   'Ed',
#   'Bpms is a tool that able  to model as is and to be. And also it able to auto the to be after modelling  Explain about the two phase?'],
#  ['09/02/2020', '11:01 pm', 'Rohit', 'descriobe how'],
#  ['09/02/2020', '11:02 pm', 'Rohit', 'HOW BPMS'],
#  ['09/02/2020', '11:02 pm', 'Rohit', 'nothing to talk about the phases'],
#  ['09/02/2020', '11:02 pm', 'Ed', 'How bpms help the phase?'],
#  ['09/02/2020',
#   '11:02 pm',
#   'Rohit',
#   'just talk what bpms directly interact inside the phase'],
#  ['09/02/2020', '11:02 pm', 'Rohit', 'ye'],
#  ['09/02/2020', '11:02 pm', 'Rohit', 'yes'],
#  ['09/02/2020', '11:02 pm', 'Ed', '<Media omitted>'],
#  ['09/02/2020', '11:03 pm', 'Rohit', 'o4 marks LOL'],
#  ['09/02/2020', '11:03 pm', 'Rohit', 'u wan explain like essay no need'],
#  ['09/02/2020',
#   '11:03 pm',
#   'Rohit',
#   'u say bpms involve in AS and provide exmaple'],
#  ['09/02/2020', '11:03 pm', 'Rohit', 'signavio process manager fro asis'],
#  ['09/02/2020', '11:03 pm', 'Rohit', 'and bpms modell to be and automate'],
#  ['09/02/2020',
#   '11:03 pm',
#   'Rohit',
#   'also signabio provess and signario worfglow'],
#  ['09/02/2020', '11:03 pm', 'Rohit', 'u get 4 marks dy'],
#  ['09/02/2020', '11:04 pm', 'Ed', 'Kk'],
#  ['09/02/2020', '11:04 pm', 'Ed', 'Sorry.. XD'],
#  ['09/02/2020',
#   '11:04 pm',
#   'Ed',
#   'Cos I did not read much on chapter 9 go through only..'],
#  ['09/02/2020',
#   '11:04 pm',
#   'Rohit',
#   'better understand the architecture tho bcuz i think exam will ouit in a manner'],
#  ['09/02/2020', '11:05 pm', 'Rohit', 'u need to adapt'],
#  ['09/02/2020', '11:05 pm', 'Rohit', 'the answer'],
#  ['09/02/2020', '11:05 pm', 'Rohit', 'to the question'],
#  ['09/02/2020', '11:05 pm', 'Ed', '.. I ser'],
#  ['09/02/2020', '11:05 pm', 'Ed', 'Never come out before in py'],
#  ['09/02/2020', '11:06 pm', 'Rohit', '2 times dy'],
#  ['09/02/2020', '11:06 pm', 'Ed', 'Ya'],
#  ['09/02/2020',
#   '11:06 pm',
#   'Rohit',
#   'if u dk the architecture sure casnt asnwer'],
#  ['09/02/2020', '11:06 pm', 'Ed', '2018 and 2019'],
#  ['09/02/2020', '11:06 pm', 'Ed', 'Kk Bro'],
#  ['09/02/2020', '11:06 pm', 'Ed', 'Fck bpm'],
#  ['09/02/2020', '11:06 pm', 'Rohit', 'wfdms throw la'],
#  ['09/02/2020', '11:06 pm', 'Rohit', 'idk also'],
#  ['09/02/2020', '11:06 pm', 'Ed', 'For so reasons'],
#  ['09/02/2020', '11:06 pm', 'Rohit', 'HAHA'],
#  ['09/02/2020',
#   '11:08 pm',
#   'Rohit',
#   'damn wei i gonna go watch mandolorian and sleep la'],
#  ['09/02/2020', '11:08 pm', 'Rohit', 'nights'],
#  ['09/02/2020', '11:08 pm', 'Rohit', 'anything u find just share la'],
#  ['09/02/2020', '11:08 pm', 'Rohit', 'at least cansee tmw or later'],
#  ['09/02/2020', '11:09 pm', 'Ed', 'Fck'],
#  ['09/02/2020', '11:10 pm', 'Rohit', '?'],
#  ['09/02/2020', '11:10 pm', 'Ed', 'I need someone'],
#  ['09/02/2020', '11:10 pm', 'Ed', '@60197773622  got anyone to intro ah'],
#  ['09/02/2020', '11:10 pm', 'Ed', 'Need to find gf 🤣🤣🤣'],
#  ['09/02/2020', '11:10 pm', 'Ed', 'Hahaha'],
#  ['09/02/2020', '11:10 pm', 'Rohit', 'hahaha yesyerday no take orange meh'],
#  ['09/02/2020', '11:10 pm', 'Rohit', 'i at klang also my fren take me'],
#  ['09/02/2020', '11:10 pm', 'Ed', 'I wait no orange'],
#  ['09/02/2020', '11:10 pm', 'Rohit', 'hahaha dope af tradition wei'],
#  ['09/02/2020', '11:10 pm', 'Ed', 'Woww'],
#  ['09/02/2020',
#   '11:20 pm',
#   'Rohit',
#   'aiya dun think too far hahaha he take me go take orange my first time participate this chap goh mei 😂 simply go je x ambik pun oren'],
#  ['09/02/2020',
#   '11:20 pm',
#   'Rohit',
#   'u should have la i see the pond damn alot wei'],
#  ['09/02/2020', '11:20 pm', 'Rohit', 'anyway sleep now gl tmr all'],
#  ['09/02/2020', '11:24 pm', 'Ed', '<Media omitted>'],
#  ['09/02/2020', '11:24 pm', 'Ed', '!!'],
#  ['09/02/2020', '11:25 pm', 'Rohit', '😂💪🏾'],
#  ['09/02/2020', '11:26 pm', 'Ed', 'See u all tmr!'],
#  ['09/02/2020', '11:28 pm', 'Ed', '<Media omitted>'],
#  ['09/02/2020', '11:28 pm', 'Ed', 'Just one last question'],
#  ['09/02/2020', '11:28 pm', 'Ed', 'iii'],
#  ['09/02/2020', '11:28 pm', 'Ed', 'Is what life cycle'],
#  ['09/02/2020', '11:29 pm', 'Rohit', 'Process owner'],
#  ['09/02/2020', '11:29 pm', 'Rohit', 'That term ah is aka ?'],
#  ['09/02/2020', '11:29 pm', 'Ed', '<Media omitted>'],
#  ['09/02/2020', '11:30 pm', 'Rohit', 'Participant is actor'],
#  ['09/02/2020', '11:30 pm', 'Ed', '10'],
#  ['09/02/2020', '11:30 pm', 'Rohit', 'Aka term'],
#  ['09/02/2020', '11:30 pm', 'Ed', '<Media omitted>'],
#  ['09/02/2020', '11:31 pm', 'Ed', '<Media omitted>'],
#  ['09/02/2020', '11:31 pm', 'Rohit', 'This is participant is actor'],
#  ['09/02/2020', '11:32 pm', 'Rohit', 'Process owner is who tho'],
#  ['09/02/2020', '11:32 pm', 'Ed', 'Boss'],
#  ['09/02/2020',
#   '11:32 pm',
#   'Ed',
#   'In the 10 got say Ower should be management'],
#  ['09/02/2020', '11:32 pm', 'Rohit', 'I cannot find also'],
#  ['09/02/2020', '11:33 pm', 'Ed', '<Media omitted>'],
#  ['09/02/2020', '11:33 pm', 'Rohit', '<Media omitted>'],
#  ['09/02/2020', '11:33 pm', 'Ed', '<Media omitted>'],
#  ['09/02/2020', '11:33 pm', 'Ed', '<Media omitted>'],
#  ['09/02/2020', '11:33 pm', 'Ed', '<Media omitted>'],
#  ['09/02/2020', '11:33 pm', 'Ed', '<Media omitted>'],
#  ['09/02/2020', '11:34 pm', 'Ed', '<Media omitted>'],
#  ['09/02/2020', '11:34 pm', 'Rohit', "Isn't that at identification"],
#  ['09/02/2020', '11:34 pm', 'Rohit', 'And process implement'],
#  ['09/02/2020', '11:35 pm', 'Rohit', 'I feel like everything Wei'],
#  ['09/02/2020', '11:35 pm', 'Ed', '<Media omitted>'],
#  ['09/02/2020', '11:35 pm', 'Ed', '<Media omitted>'],
#  ['09/02/2020', '11:36 pm', 'Ed', '<Media omitted>'],
#  ['09/02/2020', '11:36 pm', 'Ed', 'Let go sleep Wei'],
#  ['09/02/2020', '11:37 pm', 'Ed', 'Enough already haha'],
#  ['09/02/2020', '11:37 pm', 'Ed', 'Thx'],
#  ['09/02/2020', '11:37 pm', 'Ed', 'XD'],
#  ['23/04/2020', '7:27 pm', 'Ed', 'Hello guys'],
#  ['23/04/2020', '7:27 pm', 'Ed', 'Is time'],
#  ['23/04/2020', '7:27 pm', 'Ed', 'Tmr have Quiz ah? Spi'],
#  ['23/04/2020', '7:27 pm', 'Ed', '😂 😂'],
#  ['23/04/2020', '7:28 pm', 'Ed', 'Whta chapter to what chapter'],
#  ['23/04/2020', '7:29 pm', 'Rohit', 'come on pei ing open book bocor all'],
#  ['23/04/2020',
#   '7:29 pm',
#   'Rohit',
#   'i die die coding, no time to find out myslef'],
#  ...]

# %%
import datetime as dt
df = pd.DataFrame(data, columns=["Date", 'Time', 'Author', 'Message'])
df['Date'] = pd.to_datetime(df['Date'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-9-e1b51e942bda> in <cell line: 0>()
#       1 import datetime as dt
#       2 df = pd.DataFrame(data, columns=["Date", 'Time', 'Author', 'Message'])
# ----> 3 df['Date'] = pd.to_datetime(df['Date'])
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/tools/datetimes.py in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#    1061                 result = arg.tz_localize("utc")
#    1062     elif isinstance(arg, ABCSeries):
# -> 1063         cache_array = _maybe_cache(arg, format, cache, convert_listlike)
#    1064         if not cache_array.empty:
#    1065             result = arg.map(cache_array)
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/tools/datetimes.py in _maybe_cache(arg, format, cache, convert_listlike)
#     245         unique_dates = unique(arg)
#     246         if len(unique_dates) < len(arg):
# --> 247             cache_dates = convert_listlike(unique_dates, format)
#     248             # GH#45319
#     249             try:
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/tools/datetimes.py in _convert_listlike_datetimes(arg, format, name, utc, unit, errors, dayfirst, yearfirst, exact)
#     431     # `format` could be inferred, or user didn't ask for mixed-format parsing.
#     432     if format is not None and format != "mixed":
# --> 433         return _array_strptime_with_fallback(arg, name, utc, format, exact, errors)
#     434
#     435     result, tz_parsed = objects_to_datetime64(
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/tools/datetimes.py in _array_strptime_with_fallback(arg, name, utc, fmt, exact, errors)
#     465     Call array_strptime, with fallback behavior depending on 'errors'.
#     466     """
# --> 467     result, tz_out = array_strptime(arg, fmt, exact=exact, errors=errors, utc=utc)
#     468     if tz_out is not None:
#     469         unit = np.datetime_data(result.dtype)[0]
#
# strptime.pyx in pandas._libs.tslibs.strptime.array_strptime()
#
# strptime.pyx in pandas._libs.tslibs.strptime.array_strptime()
#
# strptime.pyx in pandas._libs.tslibs.strptime._parse_with_format()
#
# ValueError: time data "23/04/2020" doesn't match format "%m/%d/%Y", at position 5. You might want to try:
#     - passing `format` if your strings have a consistent format;
#     - passing `format='ISO8601'` if your strings are all ISO8601 but not necessarily in exactly the same format;
#     - passing `format='mixed'`, and the format will be inferred for each element individually. You might want to use `dayfirst` alongside this.

# %%
df
# Out:
#             Date      Time Author  \
# 0     05/02/2020  10:00 am     Ed
# 1     05/02/2020  10:01 am     Ed
# 2     05/02/2020  10:01 am     Ed
# 3     05/02/2020  10:01 am  Rohit
# 4     05/02/2020  10:01 am  Rohit
# ...          ...       ...    ...
# 4691  20/09/2020   5:32 pm     Ed
# 4692  21/09/2020   2:25 pm     Ed
# 4693  21/09/2020   2:26 pm     Ed
# 4694  21/09/2020   2:26 pm  Rohit
# 4695  21/09/2020   2:26 pm     Ed
#
#                                               Message
# 0           We share our knowledge here and pass year
# 1                                     <Media omitted>
# 2                             Easy to communicate 🤣🤣🤣
# 3                                                  💪🏾
# 4                                                yeah
# ...                                               ...
# 4691                   who have finish math lecture ?
# 4692                         You deleted this message
# 4693                                  <Media omitted>
# 4694                                          onz onz
# 4695  This is what I call English song. Good old fays
#
# [4696 rows x 4 columns]

# %%
df.tail(20)
# Out:
#             Date      Time Author  \
# 4676  18/09/2020   7:51 pm     Ed
# 4677  18/09/2020   7:51 pm  Rohit
# 4678  18/09/2020   7:51 pm  Rohit
# 4679  18/09/2020   7:51 pm  Rohit
# 4680  20/09/2020  12:51 pm     Ed
# 4681  20/09/2020  12:52 pm     Ed
# 4682  20/09/2020  12:53 pm  Rohit
# 4683  20/09/2020  12:53 pm  Rohit
# 4684  20/09/2020  12:53 pm     Ed
# 4685  20/09/2020  12:53 pm     Ed
# 4686  20/09/2020  12:53 pm     Ed
# 4687  20/09/2020  12:56 pm     Ed
# 4688  20/09/2020   1:01 pm  Rohit
# 4689  20/09/2020   1:06 pm     Ed
# 4690  20/09/2020   1:06 pm     Ed
# 4691  20/09/2020   5:32 pm     Ed
# 4692  21/09/2020   2:25 pm     Ed
# 4693  21/09/2020   2:26 pm     Ed
# 4694  21/09/2020   2:26 pm  Rohit
# 4695  21/09/2020   2:26 pm     Ed
#
#                                                 Message
# 4676                                                😂 😂
# 4677                                  She marking maybe
# 4678                           G3 few only marked right
# 4679                   I saw morning like 3 groups only
# 4680                                    <Media omitted>
# 4681                           I see kk I can hidden it
# 4682  Because we have shared alot private things her...
# 4683                                              Np np
# 4684                                    OK Bro no worry
# 4685                                 @60183560200  can?
# 4686        Then if can I credit you two in my write up
# 4687                               @60197773622  tha ya
# 4688  Hahaha I ok je la see my name on your report 😃...
# 4689                   I will censor it for the message
# 4690                                                😂 😂
# 4691                     who have finish math lecture ?
# 4692                           You deleted this message
# 4693                                    <Media omitted>
# 4694                                            onz onz
# 4695    This is what I call English song. Good old fays

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4696 entries, 0 to 4695
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Date     4696 non-null   object
#  1   Time     4696 non-null   object
#  2   Author   4696 non-null   object
#  3   Message  4696 non-null   object
# dtypes: object(4)
# memory usage: 146.9+ KB

# %%
#----- Displaying omitted media while exporting
media_messages = df[df["Message"]=='<Media omitted>'].shape[0]
print(media_messages)
# Out:
# 263

# %%
### ----------- Checking shape of dataset.
df.shape

### ---------- Checking basic information of dataset
df.info()

### ----------  Checking no. of null values in dataset
df.isnull().sum()

### ---------- Checking head part of dataset
df.head(20)

### -------- Checking tail part of dataset
df.tail(20)

### -------- Droping Nan values from dataset
df = df.dropna()
df = df.reset_index(drop=True)
df.shape

### --------- Checking no. of authors of group
df['Author'].nunique()

### --------- Checking authors of group
df['Author'].unique()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4696 entries, 0 to 4695
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Date     4696 non-null   object
#  1   Time     4696 non-null   object
#  2   Author   4696 non-null   object
#  3   Message  4696 non-null   object
# dtypes: object(4)
# memory usage: 146.9+ KB
# array(['Ed', 'Rohit'], dtype=object)

# %%
###--------  Adding one more column of "Day" for better analysis, here we use datetime library which help us to do this task easily.
weeks = {
0 : 'Monday',
1 : 'Tuesday',
2 : 'Wednesday',
3 : 'Thrusday',
4 : 'Friday',
5 : 'Saturday',
6 : 'Sunday'
}
df['Day'] = df['Date'].dt.weekday.map(weeks)

### ----------- Rearranging the columns for better understanding
df = df[['Date','Day','Time','Author','Message']]

### ----------- Changing the datatype of column "Day".
df['Day'] = df['Day'].astype('category')

### ---------- Looking newborn dataset.
df.head()

### ---------- Counting number of letters in each message
df['Letter'] = df['Message'].apply(lambda s : len(s))

### ---------- Counting number of word's in each message
df['Word'] = df['Message'].apply(lambda s : len(s.split(' ')))

### ---------- Function to count number of links in dataset, it will add extra column and store information in it.
URLPATTERN = r'(https?://\S+)'
df['urlcount'] = df.Message.apply(lambda x: regex.findall(URLPATTERN, x)).str.len()
links = np.sum(df.urlcount)

###--------- Function to count number of media in chat.
MEDIAPATTERN = r'<Media omitted>'
df['Media_Count'] = df.Message.apply(lambda x : regex.findall(MEDIAPATTERN, x)).str.len()
media = np.sum(df.Media_Count)

###------- Looking into updated dataset
df
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-15-bc0a8ff1ce14> in <cell line: 0>()
#       9 6 : 'Sunday'
#      10 }
# ---> 11 df['Day'] = df['Date'].dt.weekday.map(weeks)
#      12
#      13 ### ----------- Rearranging the columns for better understanding
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#    6300
#    6301     @final
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/accessor.py in __get__(self, obj, cls)
#     222             # we're accessing the attribute of the class, i.e., Dataset.geo
#     223             return self._accessor
# --> 224         accessor_obj = self._accessor(obj)
#     225         # Replace the property with the accessor object. Inspired by:
#     226         # https://www.pydanny.com/cached-property.html
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexes/accessors.py in __new__(cls, data)
#     641             return PeriodProperties(data, orig)
#     642
# --> 643         raise AttributeError("Can only use .dt accessor with datetimelike values")
#
# AttributeError: Can only use .dt accessor with datetimelike values

# %%
total_messages = df.shape[0]
media_messages = df[df['Message'] == '<Media omitted>'].shape[0]
links = np.sum(df.urlcount)
print('Personal Chat Stats : ')
print('Total Number of Messages : {}'.format(total_messages))
print('Total Number of Media Messages : {}'.format(media_messages))
print('Total Number of Links : {}'.format(links))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-17-1fddc251edb1> in <cell line: 0>()
#       1 total_messages = df.shape[0]
#       2 media_messages = df[df['Message'] == '<Media omitted>'].shape[0]
# ----> 3 links = np.sum(df.urlcount)
#       4 print('Personal Chat Stats : ')
#       5 print('Total Number of Messages : {}'.format(total_messages))
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#    6300
#    6301     @final
#
# AttributeError: 'DataFrame' object has no attribute 'urlcount'

# %%
l = df.Author.unique()
for i in range(len(l)):
  ### -------Filtering out messages of particular user
  req_df = df[df["Author"] == l[i]]

  ### -------- req_df will contain messages of only one particular user
  print(f'--> Stats of {l[i]} <-- ')

  ### -------- shape will print number of rows which indirectly means the number of messages
  print('Total Message Sent : ', req_df.shape[0])

  ### -------- Word_Count contains of total words in one message. Sum of all words/ Total Messages will yield words per message
  words_per_message = (np.sum(req_df['Word']))/req_df.shape[0]
  w_p_m = ("%.3f" % round(words_per_message, 2))
  print('Average Words per Message : ', w_p_m)

  ### -------- media conists of media messages
  media = sum(req_df["Media_Count"])
  print('Total Media Message Sent : ', media)

  ### ------- links consist of total links
  links = sum(req_df["urlcount"])
  print('Total Links Sent : ', links)
  print()
  print('----------------------------------------------------------n')
# Out:
# --> Stats of Ed <--
# Total Message Sent :  2140
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Word'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-18-45ec46f47c8c> in <cell line: 0>()
#      11
#      12   ### -------- Word_Count contains of total words in one message. Sum of all words/ Total Messages will yield words per message
# ---> 13   words_per_message = (np.sum(req_df['Word']))/req_df.shape[0]
#      14   w_p_m = ("%.3f" % round(words_per_message, 2))
#      15   print('Average Words per Message : ', w_p_m)
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    4100             if self.columns.nlevels > 1:
#    4101                 return self._getitem_multilevel(key)
# -> 4102             indexer = self.columns.get_loc(key)
#    4103             if is_integer(indexer):
#    4104                 indexer = [indexer]
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3810             ):
#    3811                 raise InvalidIndexError(key)
# -> 3812             raise KeyError(key) from err
#    3813         except TypeError:
#    3814             # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 'Word'

# %%
### ------ Word Cloud of mostly used word in our Group
text = " ".join(review for review in df.Message)
wordcloud = WordCloud(stopwords=STOPWORDS, background_color="white").generate(text)

### ------ Display the generated image:
plt.figure( figsize=(10,5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
###------ Creates a list of unique Authors
l = df.Author.unique()

for i in range(len(l)):
  ###------ Filtering out messages of particular user
  req_df = df[df["Author"] == l[i]]

  ###------ req_df will contain messages of only one particular user
  print(l[i],'  ->  ',req_df.shape[0])
# Out:
# Ed   ->   2140
# Rohit   ->   2556

# %%
l = df.Day.unique()
for i in range(len(l)):
  ### ------ Filtering out messages of particular user
  req_df = df[df["Day"] == l[i]]

  ###------- req_df will contain messages of only one particular user
  print(l[i],'  ->  ',req_df.shape[0])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-21-b815ce76b0fd> in <cell line: 0>()
# ----> 1 l = df.Day.unique()
#       2 for i in range(len(l)):
#       3   ### ------ Filtering out messages of particular user
#       4   req_df = df[df["Day"] == l[i]]
#       5
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#    6300
#    6301     @final
#
# AttributeError: 'DataFrame' object has no attribute 'Day'

# %%
### ------ Most Active Author in the chat
plt.figure(figsize=(9,6))
author_value_counts = df['Author'].value_counts() #--- Number of messages per author
most_active = author_value_counts.head(10) #--- Number of messages per author for the  most active author
most_active.plot.barh() #--- Plot a bar chart using pandas built-in plotting apis

plt.xlabel('No. of messages',fontdict={'fontsize': 14,'fontweight': 10})
plt.ylabel('Authors',fontdict={'fontsize': 14,'fontweight': 10})
plt.title('Mostly active member of chat',fontdict={'fontsize': 20,'fontweight': 8})
plt.show()

# %%
### ------ Mostly Active day in the chat
plt.figure(figsize=(8,5))
active_day = df['Day'].value_counts()

### ------ Most active author in the chat is :
a_d = active_day.head(10)
a_d.plot.bar()
plt.xlabel('Day',fontdict={'fontsize': 12,'fontweight': 10})
plt.ylabel('No. of messages',fontdict={'fontsize': 12,'fontweight': 10})
plt.title('Mostly active day of chat in a Week',fontdict={'fontsize': 18,'fontweight': 8})
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Day'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-23-d56a1bbd4427> in <cell line: 0>()
#       1 ### ------ Mostly Active day in the chat
#       2 plt.figure(figsize=(8,5))
# ----> 3 active_day = df['Day'].value_counts()
#       4
#       5 ### ------ Most active author in the chat is :
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    4100             if self.columns.nlevels > 1:
#    4101                 return self._getitem_multilevel(key)
# -> 4102             indexer = self.columns.get_loc(key)
#    4103             if is_integer(indexer):
#    4104                 indexer = [indexer]
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3810             ):
#    3811                 raise InvalidIndexError(key)
# -> 3812             raise KeyError(key) from err
#    3813         except TypeError:
#    3814             # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 'Day'

# %%
###------  Time whenever the chat is highly active
plt.figure(figsize=(8,5))
t = df['Time'].value_counts().head(20)
tx = t.plot.bar()
tx.yaxis.set_major_locator(MaxNLocator(integer=True))  #----- Converting y axis data to integer
plt.xlabel('Time',fontdict={'fontsize': 12,'fontweight': 10})
plt.ylabel('No. of messages',fontdict={'fontsize': 12,'fontweight': 10})
plt.title('Analysis of time when chat was highly active.',fontdict={'fontsize': 18,'fontweight': 8})
plt.show()

# %%
###---- Date on which the chat highly active.
plt.figure(figsize=(8,5))
df['Date'].value_counts().head(15).plot.bar()
plt.xlabel('Date',fontdict={'fontsize': 14,'fontweight': 10})
plt.ylabel('No. of messages',fontdict={'fontsize': 14,'fontweight': 10})
plt.title('Analysis of Date on which chat was highly active',fontdict={'fontsize': 18,'fontweight': 8})
plt.show()

# %%
lst = []
for i in df['Time']:
  out_time = datetime.strftime(datetime.strptime(i,"%I:%M %p"),"%H:%M")
  lst.append(out_time)
df['24H_Time'] = lst
df['Hours'] = df['24H_Time'].apply(lambda x : x.split(':')[0])

# %%
###------ Most suitable hour of day, whenever there will more chances of getting responce from group members.
plt.figure(figsize=(8,5))
std_time = df['Hours'].value_counts().head(15)
s_T = std_time.plot.bar()
s_T.yaxis.set_major_locator(MaxNLocator(integer=True))  #Converting y axis data to integer
plt.xlabel('Hours (24-Hour)',fontdict={'fontsize': 12,'fontweight': 10})
plt.ylabel('No. of messages',fontdict={'fontsize': 12,'fontweight': 10})
plt.title('Most suitable hour of day.',fontdict={'fontsize': 18,'fontweight': 8})
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import os
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns
import random
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics import confusion_matrix
from sklearn import metrics
from sklearn.metrics import roc_curve, auc
from nltk.stem.porter import PorterStemmer
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from sklearn.impute import SimpleImputer

# %%
# Reading Dataset
data=pd.read_csv(r"/content/drive/MyDrive/WHATSAPP_CHAT/DATASET/text.csv")
data
# Out:
#         Unnamed: 0                                               text  label
# 0                0      i just feel really helpless and heavy hearted      4
# 1                1  ive enjoyed being able to slouch about relax a...      0
# 2                2  i gave up my internship with the dmrg and am f...      4
# 3                3                         i dont know i feel so lost      0
# 4                4  i am a kindergarten teacher and i am thoroughl...      4
# ...            ...                                                ...    ...
# 416804      416804  i feel like telling these horny devils to find...      2
# 416805      416805  i began to realize that when i was feeling agi...      3
# 416806      416806  i feel very curious be why previous early dawn...      5
# 416807      416807  i feel that becuase of the tyranical nature of...      3
# 416808      416808  i think that after i had spent some time inves...      5
#
# [416809 rows x 3 columns]

# %% [markdown]
# Six categories: sadness (0), joy (1), love (2), anger (3), fear (4), and surprise (5).

# %%
data.shape
# Out:
# (416809, 3)

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'text', 'label'], dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 416809 entries, 0 to 416808
# Data columns (total 3 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   Unnamed: 0  416809 non-null  int64
#  1   text        416809 non-null  object
#  2   label       416809 non-null  int64
# dtypes: int64(2), object(1)
# memory usage: 9.5+ MB

# %%
data = data.drop('Unnamed: 0', axis=1)
data.shape
# Out:
# (416809, 2)

# %%
data.isnull().sum()
# Out:
# text     0
# label    0
# dtype: int64

# %%
label = data['label'].value_counts().reset_index()
label
# Out:
#    label   count
# 0      1  141067
# 1      0  121187
# 2      3   57317
# 3      4   47712
# 4      2   34554
# 5      5   14972

# %%
plt.figure(figsize=(8, 6))
# Get the counts of each class
class_counts = data['label'].value_counts()

# Use the index (class names) and values (counts) for the bar plot
plt.bar(class_counts.index, class_counts.values, color=['red', 'blue'])
plt.title('Class Distribution', fontsize=16)
plt.xlabel('Class', fontsize=14)
plt.ylabel('Count', fontsize=14)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.tight_layout()

# Display the graph
plt.show()

# %%
import re

def decontracted(phrase):
    # specific
    phrase = re.sub(r"won't", "will not", phrase)
    phrase = re.sub(r"can\'t", "can not", phrase)

    # general
    phrase = re.sub(r"n\'t", " not", phrase)
    phrase = re.sub(r"\'re", " are", phrase)
    phrase = re.sub(r"\'s", " is", phrase)
    phrase = re.sub(r"\'d", " would", phrase)
    phrase = re.sub(r"\'ll", " will", phrase)
    phrase = re.sub(r"\'t", " not", phrase)
    phrase = re.sub(r"\'ve", " have", phrase)
    phrase = re.sub(r"\'m", " am", phrase)
    return phrase

# %%
stopwords= ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've",\
            "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', \
            'she', "she's", 'her', 'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their',\
            'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', "that'll", 'these', 'those', \
            'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', \
            'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', \
            'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after',\
            'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further',\
            'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more',\
            'most', 'other', 'some', 'such', 'only', 'own', 'same', 'so', 'than', 'too', 'very', \
            's', 't', 'can', 'will', 'just', 'don', "don't", 'should', "should've", 'now', 'd', 'll', 'm', 'o', 're', \
            've', 'y', 'ain', 'aren', "aren't", 'couldn', "couldn't", 'didn', "didn't", 'doesn', "doesn't", 'hadn',\
            "hadn't", 'hasn', "hasn't", 'haven', "haven't", 'isn', "isn't", 'ma', 'mightn', "mightn't", 'mustn',\
            "mustn't", 'needn', "needn't", 'shan', "shan't", 'shouldn', "shouldn't", 'wasn', "wasn't", 'weren', "weren't", \
            'won', "won't", 'wouldn', "wouldn't"]

# %%
print("printing some random reviews")
print(10, data['text'].values[10])
print(100, data['text'].values[100])
print(1000, data['text'].values[1000])
# Out:
# printing some random reviews
# 10 i try to be nice though so if you get a bitchy person on the phone or at the window feel free to have a little fit and throw your pen at her face
# 100 i get the same feeling gp amp fab but then i always do
# 1000 im really feeling the pressure to provide justin friendly content

# %%
# Combining all the above stundents
from tqdm import tqdm
def preprocess_text(text_data):
    preprocessed_text = []
    # tqdm is for printing the status bar
    for sentance in tqdm(text_data):
        sent = decontracted(sentance)
        sent = sent.replace('\\r', ' ')
        sent = sent.replace('\\n', ' ')
        sent = sent.replace('\\"', ' ')
        sent = re.sub('[^A-Za-z0-9]+', ' ', str(sent))

        sent = ' '.join(e for e in sent.split() if e.lower() not in stopwords)
        preprocessed_text.append(sent.lower().strip())
    return preprocessed_text

# %%
preprocessed_text = preprocess_text(data['text'].values)
# Out:
# 100%|██████████| 416809/416809 [00:23<00:00, 17592.64it/s]

# %%
print("printing some random reviews")
print(10, preprocessed_text[10])
print(100, preprocessed_text[100])
print(1000, preprocessed_text[1000])
# Out:
# printing some random reviews
# 10 try nice though get bitchy person phone window feel free little fit throw pen face
# 100 get feeling gp amp fab always
# 1000 im really feeling pressure provide justin friendly content

# %%
data
# Out:
#                                                      text  label
# 0           i just feel really helpless and heavy hearted      4
# 1       ive enjoyed being able to slouch about relax a...      0
# 2       i gave up my internship with the dmrg and am f...      4
# 3                              i dont know i feel so lost      0
# 4       i am a kindergarten teacher and i am thoroughl...      4
# ...                                                   ...    ...
# 416804  i feel like telling these horny devils to find...      2
# 416805  i began to realize that when i was feeling agi...      3
# 416806  i feel very curious be why previous early dawn...      5
# 416807  i feel that becuase of the tyranical nature of...      3
# 416808  i think that after i had spent some time inves...      5
#
# [416809 rows x 2 columns]

# %%
#sad word cloud
import matplotlib.pyplot as plt
import wordcloud
from wordcloud import WordCloud

plt.figure(figsize=(10,10))
# Use the 'News' column instead of the 'label' column
wc=WordCloud(max_words=2000,width=1600,height=800).generate(' '.join(data[data['label']==0]['text'].astype(str)))
plt.imshow(wc , interpolation = 'bilinear')
plt.title("sad Word Cloud")
# Out:
# Text(0.5, 1.0, 'sad Word Cloud')

# %%
#joy word cloud
import matplotlib.pyplot as plt
import wordcloud
from wordcloud import WordCloud

plt.figure(figsize=(10,10))
# Use the 'News' column instead of the 'label' column
wc=WordCloud(max_words=2000,width=1600,height=800).generate(' '.join(data[data['label']==1]['text'].astype(str)))
plt.imshow(wc , interpolation = 'bilinear')
plt.title("sad Word Cloud")
# Out:
# Text(0.5, 1.0, 'sad Word Cloud')

# %%
import numpy as np
y=np.array(data['label'])

# %%
from sklearn.model_selection import train_test_split
#Breaking into Train and test
X_train, X_test, y_train, y_test = train_test_split(preprocessed_text, y, test_size=0.3,stratify=y ,random_state=42)

# %%
import pickle
from sklearn import preprocessing

count_vect = CountVectorizer()
count_trans = count_vect.fit(X_train) # fit has to happen only on train data

# Dump the file
pickle.dump(count_trans, open(r"/content/drive/MyDrive/WHATSAPP_CHAT/count_vect.pkl", "wb"))


# Testing phase
count = pickle.load(open(r"/content/drive/MyDrive/WHATSAPP_CHAT/count_vect.pkl", 'rb'))

# we use the fitted CountVectorizer to convert the text to vector
X_train_count =count.transform(X_train)
X_test_count = count.transform(X_test)

#Normalize Data
X_train_count = preprocessing.normalize(X_train_count)
print("Train Data Size: ",X_train_count.shape)

#Normalize Data
X_test_count = preprocessing.normalize(X_test_count)
print("Test Data Size: ",X_test_count.shape)
# Out:
# Train Data Size:  (291766, 63498)
# Test Data Size:  (125043, 63498)

# %%
from sklearn.metrics import accuracy_score

# %%
import xgboost as xgb
from sklearn.metrics import accuracy_score, confusion_matrix
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
import pickle

# Training XGBoost model
xgb_model = xgb.XGBClassifier(
    objective='binary:logistic',
    use_label_encoder=False,
    eval_metric='logloss',
    n_estimators=50,  # Number of trees (boosting rounds)
    max_depth=20        # Maximum depth of a tree
)
xgb_model.fit(X_train_count, y_train)

# Saving the model
filename = r'/content/drive/MyDrive/WHATSAPP_CHAT/xgboost_model.pkl'
pickle.dump(xgb_model, open(filename, 'wb'))

# Making predictions
pred_test = xgb_model.predict(X_test_count)
test_accuracy = accuracy_score(y_test, pred_test)
pred_train = xgb_model.predict(X_train_count)
train_accuracy = accuracy_score(y_train, pred_train)

# Printing accuracies
print("Accuracy on Test data is " + str(test_accuracy))
print("Accuracy on Train data is " + str(train_accuracy))

print("---------------------------")
# Out:
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [06:30:48] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# Accuracy on Test data is 0.8844877362187408
# Accuracy on Train data is 0.9378268886710583
# ---------------------------

# %%
# sadness (0), joy (1), love (2), anger (3), fear (4), and surprise (5).
# Confusion matrix and heatmap
class_names = ['sadness', 'joy','love','anger','fear','surprise']
df_heatmap = pd.DataFrame(confusion_matrix(y_test, pred_test), index=class_names, columns=class_names)
fig = plt.figure(figsize=(8, 6))
heatmap = sns.heatmap(df_heatmap, annot=True, fmt="d", cmap="Blues")
plt.title("Confusion Matrix", fontsize=16)
plt.xlabel("Predicted", fontsize=14)
plt.ylabel("Actual", fontsize=14)
plt.show()

# %%
from sklearn.metrics import accuracy_score, classification_report
class_names = ['sadness', 'joy','love','anger','fear','surprise']
print("Classification Report:")
print(classification_report(y_test, pred_test, target_names=class_names))
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#      sadness       0.95      0.92      0.93     36356
#          joy       0.92      0.89      0.91     42320
#         love       0.72      0.86      0.78     10366
#        anger       0.89      0.90      0.89     17195
#         fear       0.82      0.84      0.83     14314
#     surprise       0.66      0.73      0.69      4492
#
#     accuracy                           0.88    125043
#    macro avg       0.83      0.86      0.84    125043
# weighted avg       0.89      0.88      0.89    125043

# %%
# !pip install lightgbm
# Out:
# Requirement already satisfied: lightgbm in /usr/local/lib/python3.11/dist-packages (4.5.0)
# Requirement already satisfied: numpy>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from lightgbm) (1.26.4)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from lightgbm) (1.13.1)

# %%
from lightgbm import LGBMClassifier
lgbm = LGBMClassifier(boosting_type='goss')
lgbm.fit(X_train_count, y_train)

# Saving the model
filename = r'/content/drive/MyDrive/WHATSAPP_CHAT/lgbm_model.pkl'
pickle.dump(lgbm, open(filename, 'wb'))

# Making predictions
pred_test = lgbm.predict(X_test_count)
test_accuracy = accuracy_score(y_test, pred_test)
pred_train = lgbm.predict(X_train_count)
train_accuracy = accuracy_score(y_train, pred_train)

# Printing accuracies
print("Accuracy on Test data is " + str(test_accuracy))
print("Accuracy on Train data is " + str(train_accuracy))

print("---------------------------")
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# [LightGBM] [Warning] Found boosting=goss. For backwards compatibility reasons, LightGBM interprets this as boosting=gbdt, data_sample_strategy=goss.To suppress this warning, set data_sample_strategy=goss instead.
# [LightGBM] [Warning] Found boosting=goss. For backwards compatibility reasons, LightGBM interprets this as boosting=gbdt, data_sample_strategy=goss.To suppress this warning, set data_sample_strategy=goss instead.
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 55.899507 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 126486
# [LightGBM] [Info] Number of data points in the train set: 291766, number of used features: 8304
# [LightGBM] [Info] Using GOSS
# [LightGBM] [Info] Start training from score -1.235291
# [LightGBM] [Info] Start training from score -1.083391
# [LightGBM] [Info] Start training from score -2.490095
# [LightGBM] [Info] Start training from score -1.984027
# [LightGBM] [Info] Start training from score -2.167456
# [LightGBM] [Info] Start training from score -3.326483
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# [LightGBM] [Warning] Found boosting=goss. For backwards compatibility reasons, LightGBM interprets this as boosting=gbdt, data_sample_strategy=goss.To suppress this warning, set data_sample_strategy=goss instead.
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# [LightGBM] [Warning] Found boosting=goss. For backwards compatibility reasons, LightGBM interprets this as boosting=gbdt, data_sample_strategy=goss.To suppress this warning, set data_sample_strategy=goss instead.
# Accuracy on Test data is 0.9055125036987276
# Accuracy on Train data is 0.9156584386117642
# ---------------------------

# %%
# Confusion matrix and heatmap
class_names = ['sadness', 'joy','love','anger','fear','surprise']
df_heatmap = pd.DataFrame(confusion_matrix(y_test, pred_test), index=class_names, columns=class_names)
fig = plt.figure(figsize=(8, 6))
heatmap = sns.heatmap(df_heatmap, annot=True, fmt="d", cmap="Blues")
plt.title("Confusion Matrix", fontsize=16)
plt.xlabel("Predicted", fontsize=14)
plt.ylabel("Actual", fontsize=14)
plt.show()

# %%
from sklearn.metrics import accuracy_score, classification_report
class_names = ['sadness', 'joy','love','anger','fear','surprise']
print("Classification Report:")
print(classification_report(y_test, pred_test, target_names=class_names))
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#      sadness       0.96      0.92      0.94     36356
#          joy       0.96      0.89      0.93     42320
#         love       0.76      0.91      0.83     10366
#        anger       0.88      0.94      0.91     17195
#         fear       0.85      0.87      0.86     14314
#     surprise       0.72      0.81      0.76      4492
#
#     accuracy                           0.91    125043
#    macro avg       0.85      0.89      0.87    125043
# weighted avg       0.91      0.91      0.91    125043

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import accuracy_score, confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt
from tensorflow import keras
from tensorflow.keras import layers, models
import pickle

# Load Dataset
dataset_path = r'/content/drive/MyDrive/WHATSAPP_CHAT/DATASET/text.csv'
df = pd.read_csv(dataset_path)

# Data Overview
print(df.head())
print(df['label'].value_counts())

# Preprocessing
X = df['text']
y = df['label']

# Label Encoding
label_encoder = LabelEncoder()
y_encoded = label_encoder.fit_transform(y)

# Train-Test Split
X_train, X_test, y_train, y_test = train_test_split(X, y_encoded, test_size=0.2, random_state=42, stratify=y_encoded)

# Count Vectorization with Reduced Features
count_vectorizer = CountVectorizer(max_features=1000)
X_train_counts = count_vectorizer.fit_transform(X_train)
X_test_counts = count_vectorizer.transform(X_test)

# Convert Sparse to Dense only before training
X_train_dense = X_train_counts.toarray()
X_test_dense = X_test_counts.toarray()

# Reshape for LSTM (samples, timesteps, features)
X_train_reshaped = np.expand_dims(X_train_dense, axis=1)
X_test_reshaped = np.expand_dims(X_test_dense, axis=1)

# Save Count Vectorizer
vectorizer_path = r'/content/drive/MyDrive/WHATSAPP_CHAT/count_vectorizer.pkl'
pickle.dump(count_vectorizer, open(vectorizer_path, 'wb'))

# Build LSTM Model with Fewer Units
lstm_units = 32
num_classes = len(label_encoder.classes_)
epochs = 10
batch_size = 32

model = models.Sequential()
model.add(layers.Input(shape=(1, X_train_dense.shape[1])))
model.add(layers.LSTM(lstm_units, dropout=0.2, recurrent_dropout=0.2))
model.add(layers.Dense(num_classes, activation='softmax'))

# Compile Model
model.compile(loss='sparse_categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
model.summary()

# Train the Model with Smaller Batches
history = model.fit(X_train_reshaped, y_train, validation_split=0.2, epochs=epochs, batch_size=batch_size, verbose=1)

# Save LSTM Model
model_path = r'/content/drive/MyDrive/WHATSAPP_CHAT/lstm_model.h5'
model.save(model_path)

# Predictions
y_pred_train = np.argmax(model.predict(X_train_reshaped), axis=1)
y_pred_test = np.argmax(model.predict(X_test_reshaped), axis=1)

# Accuracy
train_accuracy = accuracy_score(y_train, y_pred_train)
test_accuracy = accuracy_score(y_test, y_pred_test)
print("Accuracy on Train data: {:.2f}%".format(train_accuracy * 100))
print("Accuracy on Test data: {:.2f}%".format(test_accuracy * 100))

# Confusion Matrix
class_names = label_encoder.classes_
df_heatmap = pd.DataFrame(confusion_matrix(y_test, y_pred_test), index=class_names, columns=class_names)
fig = plt.figure(figsize=(8, 6))
sns.heatmap(df_heatmap, annot=True, fmt="d")
plt.title('Confusion Matrix - LSTM')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()
# Out:
#    Unnamed: 0                                               text  label
# 0           0      i just feel really helpless and heavy hearted      4
# 1           1  ive enjoyed being able to slouch about relax a...      0
# 2           2  i gave up my internship with the dmrg and am f...      4
# 3           3                         i dont know i feel so lost      0
# 4           4  i am a kindergarten teacher and i am thoroughl...      4
# label
# 1    141067
# 0    121187
# 3     57317
# 4     47712
# 2     34554
# 5     14972
# Name: count, dtype: int64
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                     │ (None, 32)             │       132,224 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 6)              │           198 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 132,422 (517.27 KB)
#  Trainable params: 132,422 (517.27 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/10
# 8337/8337 ━━━━━━━━━━━━━━━━━━━━ 79s 9ms/step - accuracy: 0.7100 - loss: 0.8089 - val_accuracy: 0.8552 - val_loss: 0.3692
# Epoch 2/10
# 8337/8337 ━━━━━━━━━━━━━━━━━━━━ 83s 9ms/step - accuracy: 0.8453 - loss: 0.4240 - val_accuracy: 0.8560 - val_loss: 0.3566
# Epoch 3/10
# 8337/8337 ━━━━━━━━━━━━━━━━━━━━ 81s 9ms/step - accuracy: 0.8488 - loss: 0.4023 - val_accuracy: 0.8575 - val_loss: 0.3490
# Epoch 4/10
# 8337/8337 ━━━━━━━━━━━━━━━━━━━━ 80s 9ms/step - accuracy: 0.8542 - loss: 0.3800 - val_accuracy: 0.8567 - val_loss: 0.3445
# Epoch 5/10
# 8337/8337 ━━━━━━━━━━━━━━━━━━━━ 82s 9ms/step - accuracy: 0.8563 - loss: 0.3695 - val_accuracy: 0.8564 - val_loss: 0.3420
# Epoch 6/10
# 8337/8337 ━━━━━━━━━━━━━━━━━━━━ 75s 9ms/step - accuracy: 0.8600 - loss: 0.3522 - val_accuracy: 0.8555 - val_loss: 0.3399
# Epoch 7/10
# 8337/8337 ━━━━━━━━━━━━━━━━━━━━ 75s 9ms/step - accuracy: 0.8603 - loss: 0.3466 - val_accuracy: 0.8552 - val_loss: 0.3382
# Epoch 8/10
# 8337/8337 ━━━━━━━━━━━━━━━━━━━━ 75s 9ms/step - accuracy: 0.8635 - loss: 0.3360 - val_accuracy: 0.8545 - val_loss: 0.3376
# Epoch 9/10
# 8337/8337 ━━━━━━━━━━━━━━━━━━━━ 74s 9ms/step - accuracy: 0.8649 - loss: 0.3313 - val_accuracy: 0.8541 - val_loss: 0.3390
# Epoch 10/10
# 8337/8337 ━━━━━━━━━━━━━━━━━━━━ 82s 9ms/step - accuracy: 0.8668 - loss: 0.3257 - val_accuracy: 0.8542 - val_loss: 0.3402
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 10421/10421 ━━━━━━━━━━━━━━━━━━━━ 22s 2ms/step
# 2606/2606 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step
# Accuracy on Train data: 87.79%
# Accuracy on Test data: 85.43%

# %%
from sklearn.metrics import accuracy_score, classification_report
class_names = ['sadness', 'joy','love','anger','fear','surprise']
print("Classification Report:")
print(classification_report(y_test, y_pred_test, target_names=class_names))
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#      sadness       0.89      0.91      0.90     24238
#          joy       0.87      0.89      0.88     28214
#         love       0.75      0.78      0.76      6911
#        anger       0.84      0.82      0.83     11463
#         fear       0.84      0.74      0.79      9542
#     surprise       0.77      0.67      0.72      2994
#
#     accuracy                           0.85     83362
#    macro avg       0.83      0.80      0.81     83362
# weighted avg       0.85      0.85      0.85     83362
